# %%
import xesmf as xe
from glob import glob
import matplotlib.pyplot as plt
import gc
import xarray as xr
import pandas as pd
import xrft as xrft
from scipy.interpolate import griddata
from scipy.ndimage import gaussian_filter as gauss
from matplotlib.colors import LogNorm
import xroms
import numpy as np
import seawater as sw

import sys
sys.path.append("/homes/metogra/iufarias/Documents/Scripts/useful")
import romspickle as rp

from dask.diagnostics import ProgressBar
import dask
dask.config.set(**{'array.slicing.split_large_chunks': True})
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_65468/2901186212.py in <module>
# ----> 1 import xesmf as xe
#       2 from glob import glob
#       3 import matplotlib.pyplot as plt
#       4 import gc
#       5 import xarray as xr
#
# ModuleNotFoundError: No module named 'xesmf'

# %%
import warnings

warnings.filterwarnings("ignore")

# %%
chunks={'time':1, 's_rho':10, 's_w':10}

#3D
path='/data/pacific/lrenault/SASI/CROCO/FULL/'
listm=glob(path+'SASI*.nc');listm.sort()
# varf=xr.open_dataset(listm[0])
varf=xr.open_mfdataset(listm,data_vars='minimal', chunks=chunks)


path='/data/pacific/lrenault/SASI/CROCO/SMTH/'
listt=glob(path+'SASI*.nc');listt.sort()
#vart=xr.open_dataset(listt[xmon])
vart=xr.open_mfdataset(listt, data_vars='minimal', chunks=chunks)

# %%
# varx = varf.rename({"time_counter":"ocean_time","x_rho": "xi_rho","x_u":"xi_u","x_v":"xi_v","x_w":"xi_w",
#                     "y_rho":"eta_rho","y_v":"eta_v","y_u":"eta_u","y_w":"eta_w","s_rho":"s_rho","s_w":"s_w"})

# varx = varf.rename({"time_counter":"ocean_time","x_rho": "xi_rho","x_u":"xi_u",
#                     "y_rho":"eta_rho","y_v":"eta_v"})

# %%
# varx=varx.assign_coords(xi_rho=("xi_rho",varx.xi_rho.data),eta_rho=("eta_rho",varx.eta_rho.data),
#                   xi_u=("xi_u",varx.xi_u.data),eta_u=("eta_u",varx.eta_u.data),
#                   xi_v=("xi_v",varx.xi_v.data),eta_v=("eta_v",varx.eta_v.data),
#                   xi_w=("xi_w",varx.xi_w.data),eta_w=("eta_w",varx.eta_w.data))

# varx=varx.assign_coords(xi_rho=("xi_rho",varx.xi_rho.data),eta_rho=("eta_rho",varx.eta_rho.data),
#                   xi_u=("xi_u",varx.xi_u.data),eta_v=("eta_v",varx.eta_v.data))

# %%
# zf=rp.zlevs(h=varf.h.to_numpy(),zeta=varf.zeta[0].to_numpy(),
#          theta_s=np.int(varf.theta_s),theta_b=np.int(varf.theta_b),
#          hc=np.int(varf.hc),N=80)

# zt=rp.zlevs(h=varf.h.to_numpy(),zeta=varf.zeta[0].to_numpy(),
#          theta_s=np.int(varf.theta_s),theta_b=np.int(varf.theta_b),
#          hc=np.int(varf.hc),N=80)

# %%
# varf=varf.assign_coords(z_rho=(('s_rho','y_rho','x_rho'),zf))
# vart=vart.assign_coords(z_rho=(('s_rho','y_rho','x_rho'),zt))

# %%
varx = varf.rename({"time_counter":"ocean_time","x_rho": "xi_rho","x_u":"xi_u","x_v":"xi_v","x_w":"xi_w",
                    "y_rho":"eta_rho","y_v":"eta_v","y_u":"eta_u","y_w":"eta_w","s_rho":"s_rho","s_w":"s_w"})
df,gf=xroms.roms_dataset(varx,Vtransform=2)


vary = vart.rename({"time_counter":"ocean_time","x_rho": "xi_rho","x_u":"xi_u","x_v":"xi_v",
                    "y_rho":"eta_rho","y_v":"eta_v","y_u":"eta_u"})
dt,gt=xroms.roms_dataset(vary,Vtransform=2)

# %%
del varx,vary,varf,vart

# %%
# df=df.assign_coords(z_rho=(('s_rho','eta_rho','xi_rho'),zf))
# dt=dt.assign_coords(z_rho=(('s_rho','eta_rho','xi_rho'),zt))

# %%
tf=df.temp.groupby("ocean_time.dayofyear").mean();
tf=tf[0,-15:-1,200:1350,20:850]
# tf=tf.isel(s_rho=range(-15,-1),xi_rho=range(20,850));
# tf=tf.isel(eta_rho=range(100,1300));
# tf=tf.compute()

sf=df.salt.groupby("ocean_time.dayofyear").mean();
sf=sf[0,-15:-1,200:1350,20:850]

# %%
sf=sf.compute()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_97008/2105211842.py in <module>
# ----> 1 sf=sf.compute()
#
# ~/miniconda3/envs/ROMS/lib/python3.7/site-packages/xarray/core/dataarray.py in compute(self, **kwargs)
#     949         """
#     950         new = self.copy(deep=False)
# --> 951         return new.load(**kwargs)
#     952
#     953     def persist(self, **kwargs) -> "DataArray":
#
# ~/miniconda3/envs/ROMS/lib/python3.7/site-packages/xarray/core/dataarray.py in load(self, **kwargs)
#     923         dask.compute
#     924         """
# --> 925         ds = self._to_temp_dataset().load(**kwargs)
#     926         new = self._from_temp_dataset(ds)
#     927         self._variable = new._variable
#
# ~/miniconda3/envs/ROMS/lib/python3.7/site-packages/xarray/core/dataset.py in load(self, **kwargs)
#     860
# ...

# %%
# Bf=np.zeros([214,14, 1200, 850])*np.nan

# for idd in np.arange(0,852,4):
# tf=df.temp.isel(ocean_time=idd,s_rho=range(-15,-1),xi_rho=range(850));tf=tf.isel(eta_rho=range(100,1300)).compute()
# sf=df.salt.isel(ocean_time=idd,s_rho=range(-15,-1),xi_rho=range(850));sf=sf.isel(eta_rho=range(100,1300)).compute()
tf=df.temp.groupby("ocean_time.dayofyear").mean();
tf=tf.isel(s_rho=range(-15,-1),xi_rho=range(850));
tf=tf.isel(eta_rho=range(100,1300));

sf=df.salt.groupby("ocean_time.dayofyear").mean().isel(s_rho=range(-15,-1),xi_rho=range(850),eta_rho=range(100,1300))

rhof=xroms.potential_density(tf,sf)
bf=xroms.buoyancy(rhof)
# Bf[idd,:,:,:]=bf

# %%
tt=dt.temp.groupby("ocean_time.dayofyear").mean().isel(s_rho=range(-15,-1),xi_rho=range(850),eta_rho=range(100,1300))
st=dt.salt.groupby("ocean_time.dayofyear").mean().isel(s_rho=range(-15,-1),xi_rho=range(850),eta_rho=range(100,1300))

rhot=xroms.potential_density(tt,st)
bt=xroms.buoyancy(rhot)
# Out:
# 216

# %%
Bt=np.zeros([214,14, 1200, 850])*np.nan

for idd in np.arange(0,852,4):
    tt=dt.temp.isel(ocean_time=0,s_rho=range(-15,-1),xi_rho=range(850));tf=tf.isel(eta_rho=range(100,1300)).compute()
    st=dt.salt.isel(ocean_time=0,s_rho=range(-15,-1),xi_rho=range(850));sf=sf.isel(eta_rho=range(100,1300)).compute()
    rhof=xroms.potential_density(tf,sf)
    bf=xroms.buoyancy(rhof)
    Bf[idd,:,:,:]=bf

# %%
bf.shape
# Out:
# (14, 1200, 850)

# %%
tf=varf.temp[:,-1,50:-50,50:840].groupby("time_counter.dayofyear").mean().compute()

# %%
tf=varf.temp.groupby("time_counter.dayofyear").mean()[:,:-15,200:-200,90:700]
sf=varf.temp.groupby("time_counter.dayofyear").mean()[:,:-15,200:-200,90:700]
wf=varf.temp.groupby("time_counter.dayofyear").mean()[:,:-15,200:-200,90:700]

tt=vart.temp.groupby("time_counter.dayofyear").mean()[:,:-15,200:-200,90:700]
st=vart.temp.groupby("time_counter.dayofyear").mean()[:,:-15,200:-200,90:700]
wt=vart.temp.groupby("time_counter.dayofyear").mean()[:,:-15,200:-200,90:700]

# %%
rhof=xroms.potential_density(tf,sf)

rhot=xroms.potential_density(tt,st)
# rhot=xroms.potential_density(dt.temp,dt.salt)
# Out:
# /homes/metogra/iufarias/miniconda3/envs/ROMS/lib/python3.7/site-packages/dask/array/core.py:405: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   o = func(*args, **kwargs)
# /homes/metogra/iufarias/miniconda3/envs/ROMS/lib/python3.7/site-packages/dask/array/core.py:405: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   o = func(*args, **kwargs)

# %%
bf=xroms.buoyancy(rhof)
bt=xroms.buoyancy(rhot)

# %%
Bf=bf.compute()
Bt=bt.compute()
Wf=wf.compute()
Wt=wt.compute()

# %%
exspec=xrft.isotropic_power_spectrum(bf[0,0,:,:],nfactor=2,truncate='True',detrend='linear', window=True)

VBPf=np.zeros([Bf.shape[0],Bf.shape[1],exspec.shape[0]])*np.nan;
VBPt=np.zeros([Bt.shape[0],Bt.shape[1],exspec.shape[0]])*np.nan;

for idd in range(Bf.shape[0]):
    for izz in range(Bf.shape[1]):
        print(ixx,end=' ',flush=True)

        bbf=xrft.isotropic_power_spectrum(uf[idd,izz,:,:],nfactor=2,truncate='True',detrend='linear', window=True)
        wwf=xrft.isotropic_power_spectrum(vf[idd,izz,:,:],nfactor=2,truncate='True',detrend='linear', window=True)

        bbt=xrft.isotropic_power_spectrum(ut[idd,izz,:,:],nfactor=2,truncate='True',detrend='linear', window=True)
        wwt=xrft.isotropic_power_spectrum(vt[idd,izz,:,:],nfactor=2,truncate='True',detrend='linear', window=True)


        Ekef[ixx,:]=0.5*(upf.to_numpy()+vpf.to_numpy())
        Eket[ixx,:]=0.5*(upt.to_numpy()+vpt.to_numpy())
# Out:
# /homes/metogra/iufarias/miniconda3/envs/ROMS/lib/python3.7/site-packages/xrft/xrft.py:51: FutureWarning: Please provide the name of window adhering to scipy.signal.windows. The boolean option will be deprecated in future releases.
#   FutureWarning,

# %%
aa.compute()
# Out:
# <xarray.DataArray (freq_r: 0)>
# array([], dtype=float64)
# Coordinates:
#     ocean_time  datetime64[ns] 2011-12-01T12:00:00
#   * freq_r      (freq_r) float64

# %% [markdown]
# ### Mixed Layer Depth

# %%
xroms.mld(sig0=df.xroms.sig0,h=df.h,mask=df.mask_rho,z=df.s_rho,thresh=0.03)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_86552/3099461963.py in <module>
# ----> 1 xroms.mld(sig0=df.xroms.sig0,h=df.h,mask=df.mask_rho,z=df.s_rho,thresh=0.03)
#
# ~/miniconda3/envs/ROMS/lib/python3.7/site-packages/xroms-0.0.0-py3.7.egg/xroms/roms_seawater.py in mld(sig0, h, mask, z, thresh)
#     434         sig0.attrs["grid"],
#     435         iso_array=sig0 - sig0.isel(s_rho=-1) - thresh,
# --> 436         axis="Z",
#     437     )
#     438     #     mld = xroms.xisoslice(sig0 - sig0.isel(s_rho=-1) - thresh, 0.0, z, skey)
#
# ~/miniconda3/envs/ROMS/lib/python3.7/site-packages/xroms-0.0.0-py3.7.egg/xroms/interp.py in isoslice(var, iso_values, grid, iso_array, axis)
#     236
#     237     # perform interpolation
# --> 238     transformed = grid.transform(var, axis, iso_values, target_data=iso_array)
#     239
# ...

# %%
df.xroms.sig0
# Out:
# <xarray.DataArray 'sig0' (ocean_time: 852, s_rho: 80, eta_rho: 1520, xi_rho: 1000)>
# dask.array<truediv, shape=(852, 80, 1520, 1000), dtype=float32, chunksize=(124, 80, 1520, 1000), chunktype=numpy.ndarray>
# Coordinates:
#     nav_lat_rho  (eta_rho, xi_rho) float32 dask.array<chunksize=(1520, 1000), meta=np.ndarray>
#     nav_lon_rho  (eta_rho, xi_rho) float32 dask.array<chunksize=(1520, 1000), meta=np.ndarray>
#   * ocean_time   (ocean_time) datetime64[ns] 2011-12-01T06:00:00 ... 2012-07-01
#   * xi_rho       (xi_rho) int64 0 1 2 3 4 5 6 7 ... 993 994 995 996 997 998 999
#   * eta_rho      (eta_rho) int64 0 1 2 3 4 5 6 ... 1514 1515 1516 1517 1518 1519
# Dimensions without coordinates: s_rho
# Attributes:
#     long_name:           potential density
#     units:               kg/m^3
#     online_operation:    instant
#     interval_operation:  6 h
#     interval_write:      6 h
#     cell_methods:        time: point
# ...
