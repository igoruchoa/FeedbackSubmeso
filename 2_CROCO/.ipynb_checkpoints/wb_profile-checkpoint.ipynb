# %%
import numpy as np
import xroms
from glob import glob
import matplotlib.pyplot as plt
import gc
import xarray as xr
import pandas as pd
import xrft as xrft
import warnings
import sys
import xrft
# import seaborn as sns
sys.path.append("/homes/metogra/iufarias/FeedbackSubmeso/useful/")
import romspickle

from dask.diagnostics import ProgressBar
import dask
dask.config.set(**{'array.slicing.split_large_chunks': True})
from dask.distributed import Client 


import scipy.integrate as integ
warnings.filterwarnings("ignore")

# %%
client = Client(memory_limit='400GB',n_workers=120)

# %%
client
# Out:
# <Client: 'tcp://127.0.0.1:41596' processes=120 threads=240, memory=43.66 TiB>

# %% [markdown]
# ## Reading CROCO (3D)

# %%
chunks={'time_counter':2, 'x_rho':1000, 'y_rho':1520,'s_rho':80,'s_w':80}
path='/data/pacific/lrenault/SASI/CROCO/'

varf=xr.open_mfdataset(path + 'FULL/SASI*2012*.nc',data_vars='minimal',chunks=chunks)
vart=xr.open_mfdataset(path + 'SMTH/SASI*2012*.nc',data_vars='minimal',chunks=chunks)

# varf=xr.open_mfdataset(path + 'FULL/SASI*2012*.nc',data_vars='minimal',chunks=chunks)
# vart=xr.open_mfdataset(path + 'SMTH/SASI*2012*.nc',data_vars='minimal',chunks=chunks)

# %% [markdown]
# Converting to xroms

# %%
varx = varf.rename({"time_counter":"ocean_time","x_rho": "xi_rho","x_u":"xi_u","x_v":"xi_v","x_w":"xi_w",
                    "y_rho":"eta_rho","y_v":"eta_v","y_u":"eta_u","y_w":"eta_w","s_rho":"s_rho","s_w":"s_w"})
df,gf=xroms.roms_dataset(varx,Vtransform=varx.Vtransform.data)

vary = vart.rename({"time_counter":"ocean_time","x_rho": "xi_rho","x_u":"xi_u","x_v":"xi_v",
                    "y_rho":"eta_rho","y_v":"eta_v","y_u":"eta_u","y_w":"eta_w","s_rho":"s_rho","s_w":"s_w"})
dt,gt=xroms.roms_dataset(vary,Vtransform=vary.Vtransform.data)

# %%
# plt.rcParams['text.usetex'] = True
# plt.rcParams.update({'font.size': 22})

# plt.rcParams['font.family'] = 'sans-serif'
# plt.rcParams['font.sans-serif'] = ['Lucida Grande']

# %%
timer_h=pd.DatetimeIndex(dt.ocean_time)
timer_d=pd.DatetimeIndex(dt.ocean_time.groupby("ocean_time.dayofyear").mean())

# %% [markdown]
# #### Spectral parameters

# %%
dx=0.5
nf=2
wdws='hann' #'flattop','hann'
wdw_cor=True
scl='density'

# %% [markdown]
# #### EKE (FULL)

# %%
v_full_psi
# Out:
# <xarray.DataArray 'v' (ocean_time: 728, s_rho: 80, eta_v: 1519, xi_u: 999)>
# dask.array<mul, shape=(728, 80, 1519, 999), dtype=float32, chunksize=(6, 80, 1519, 999), chunktype=numpy.ndarray>
# Coordinates:
#   * s_rho         (s_rho) float32 -0.9937 -0.9812 -0.9688 ... -0.01875 -0.00625
#     time_instant  (ocean_time) datetime64[ns] dask.array<chunksize=(6,), meta=np.ndarray>
#   * ocean_time    (ocean_time) datetime64[ns] 2012-01-01T06:00:00 ... 2012-07-01
#   * xi_u          (xi_u) int64 0 1 2 3 4 5 6 7 ... 992 993 994 995 996 997 998
#   * eta_v         (eta_v) int64 0 1 2 3 4 5 6 ... 1513 1514 1515 1516 1517 1518
#     z_rho_psi     (ocean_time, s_rho, eta_v, xi_u) float64 dask.array<chunksize=(6, 80, 1519, 999), meta=np.ndarray>
#     z_rho_psi0    (s_rho, eta_v, xi_u) float64 dask.array<chunksize=(80, 1519, 999), meta=np.ndarray>
# Attributes:
#     long_name:           v-momentum component
#     units:               meter second-1
#     online_operation:    instant
#     interval_operation:  6 h
#     interval_write:      6 h
#     cell_methods:        time: point
#     grid:                <xgcm.Grid>\nX Axis (not periodic, boundary=None):\n...
#     name:                v

# %%
v_full_psi=df.v.xroms.to_grid('psi', 's_rho')
v_full_interp=v_full_psi.xroms.isoslice(np.linspace(-5,-50, 10))[:,:,120:-120,120:800]

# %%
u_full_psi=df.u.xroms.to_grid('psi', 's_rho')
u_full_interp=u_full_psi.xroms.isoslice(np.linspace(-5,-50, 10))[:,:,120:-120,120:800]

# %%
# %%time

with ProgressBar():
    Uf=xrft.isotropic_power_spectrum(u_full_interp,
                                      dim=['eta_v','xi_u'],
                              nfactor=nf,truncate='True',scaling=scl,detrend='linear', 
                                     window=wdws,window_correction=wdw_cor)
# Out:
# 2023-05-05 15:43:16,793 - distributed.worker - ERROR - Worker stream died during communication: tcp://127.0.0.1:39091
# Traceback (most recent call last):
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/asyncio/tasks.py", line 465, in wait_for
#     fut.result()
# asyncio.exceptions.CancelledError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/comm/core.py", line 329, in connect
#     await asyncio.wait_for(comm.write(local_info), time_left())
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/asyncio/tasks.py", line 467, in wait_for
#     raise exceptions.TimeoutError() from exc
# asyncio.exceptions.TimeoutError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/worker.py", line 2016, in gather_dep
#     response = await get_data_from_worker(
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/worker.py", line 2805, in get_data_from_worker
#     return await retry_operation(_get_data, operation="get_data_from_worker")
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/utils_comm.py", line 383, in retry_operation
#     return await retry(
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/utils_comm.py", line 368, in retry
#     return await coro()
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/worker.py", line 2782, in _get_data
#     comm = await rpc.connect(worker)
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/core.py", line 1372, in connect
#     return await connect_attempt
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/core.py", line 1308, in _connect
#     comm = await connect(
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/comm/core.py", line 333, in connect
#     raise OSError(
# OSError: Timed out during handshake while connecting to tcp://127.0.0.1:39091 after 30 s
# 2023-05-05 15:43:16,795 - distributed.worker - ERROR - Worker stream died during communication: tcp://127.0.0.1:35083
# Traceback (most recent call last):
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/asyncio/tasks.py", line 465, in wait_for
#     fut.result()
# asyncio.exceptions.CancelledError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/comm/core.py", line 329, in connect
#     await asyncio.wait_for(comm.write(local_info), time_left())
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/asyncio/tasks.py", line 467, in wait_for
#     raise exceptions.TimeoutError() from exc
# asyncio.exceptions.TimeoutError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/worker.py", line 2016, in gather_dep
#     response = await get_data_from_worker(
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/worker.py", line 2805, in get_data_from_worker
#     return await retry_operation(_get_data, operation="get_data_from_worker")
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/utils_comm.py", line 383, in retry_operation
#     return await retry(
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/utils_comm.py", line 368, in retry
#     return await coro()
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/worker.py", line 2782, in _get_data
#     comm = await rpc.connect(worker)
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/core.py", line 1372, in connect
#     return await connect_attempt
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/core.py", line 1308, in _connect
#     comm = await connect(
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/comm/core.py", line 333, in connect
#     raise OSError(
# OSError: Timed out during handshake while connecting to tcp://127.0.0.1:35083 after 30 s
# 2023-05-05 16:15:46,846 - distributed.worker - ERROR - Worker stream died during communication: tcp://127.0.0.1:37654
# Traceback (most recent call last):
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/comm/core.py", line 328, in connect
#     handshake = await asyncio.wait_for(comm.read(), time_left())
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/asyncio/tasks.py", line 501, in wait_for
#     raise exceptions.TimeoutError()
# asyncio.exceptions.TimeoutError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/worker.py", line 2016, in gather_dep
#     response = await get_data_from_worker(
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/worker.py", line 2805, in get_data_from_worker
#     return await retry_operation(_get_data, operation="get_data_from_worker")
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/utils_comm.py", line 383, in retry_operation
#     return await retry(
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/utils_comm.py", line 368, in retry
#     return await coro()
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/worker.py", line 2782, in _get_data
#     comm = await rpc.connect(worker)
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/core.py", line 1372, in connect
#     return await connect_attempt
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/core.py", line 1308, in _connect
#     comm = await connect(
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/comm/core.py", line 333, in connect
#     raise OSError(
# OSError: Timed out during handshake while connecting to tcp://127.0.0.1:37654 after 30 s
# 2023-05-05 16:17:31,835 - distributed.nanny - WARNING - Restarting worker
# 2023-05-05 16:18:28,062 - distributed.worker - WARNING - Compute Failed
# Key:       ('transpose-6a2df7944d27cd5ce4bd34028b53a47c', 15, 0, 0, 0)
# Function:  subgraph_callable-f0e6aab0-ba87-4326-a232-c89389e1
# args:      (array([[[[-9.93846700e-01, -9.93846620e-01, -9.93846645e-01, ...,
#                       nan,             nan,             nan],
#          [-9.93846619e-01, -9.93846648e-01, -9.93846678e-01, ...,
#                       nan,             nan,             nan],
#          [-9.93846639e-01, -9.93846674e-01, -9.93846703e-01, ...,
#                       nan,             nan,             nan],
#          ...,
#          [-9.93846882e-01, -9.93846897e-01, -9.93846912e-01, ...,
#                       nan,             nan,             nan],
#          [-9.93846894e-01, -9.93846912e-01, -9.93846927e-01, ...,
#                       nan,             nan,             nan],
#          [-9.93846910e-01, -9.93846924e-01, -9.93846941e-01, ...,
#                       nan,             nan,             nan]],
#
#         [[-9.80228734e-01, -9.80228737e-01, -9.80228744e-01, ...,
#                       nan,             nan,             nan],
#          [-9.80228754e-01, -9.80228774e-01, -9.80228793e-01, ...,
#
# kwargs:    {}
# Exception: "MemoryError((6, 1520, 1000, 80), dtype('float64'))"
#
# 2023-05-05 16:18:33,375 - distributed.worker - WARNING - Compute Failed
# Key:       ('transpose-6a2df7944d27cd5ce4bd34028b53a47c', 63, 0, 0, 0)
# Function:  subgraph_callable-f0e6aab0-ba87-4326-a232-c89389e1
# args:      (array([[[[-9.93846700e-01, -9.93846620e-01, -9.93846645e-01, ...,
#                       nan,             nan,             nan],
#          [-9.93846619e-01, -9.93846648e-01, -9.93846678e-01, ...,
#                       nan,             nan,             nan],
#          [-9.93846639e-01, -9.93846674e-01, -9.93846703e-01, ...,
#                       nan,             nan,             nan],
#          ...,
#          [-9.93846882e-01, -9.93846897e-01, -9.93846912e-01, ...,
#                       nan,             nan,             nan],
#          [-9.93846894e-01, -9.93846912e-01, -9.93846927e-01, ...,
#                       nan,             nan,             nan],
#          [-9.93846910e-01, -9.93846924e-01, -9.93846941e-01, ...,
#                       nan,             nan,             nan]],
#
#         [[-9.80228734e-01, -9.80228737e-01, -9.80228744e-01, ...,
#                       nan,             nan,             nan],
#          [-9.80228754e-01, -9.80228774e-01, -9.80228793e-01, ...,
#
# kwargs:    {}
# Exception: "MemoryError((6, 1520, 1000, 80), dtype('float64'))"
#
# 2023-05-05 16:18:33,375 - distributed.worker - WARNING - Compute Failed
# Key:       ('transpose-6a2df7944d27cd5ce4bd34028b53a47c', 32, 0, 0, 0)
# Function:  subgraph_callable-f0e6aab0-ba87-4326-a232-c89389e1
# args:      (array([[[[-9.93846700e-01, -9.93846620e-01, -9.93846645e-01, ...,
#                       nan,             nan,             nan],
#          [-9.93846619e-01, -9.93846648e-01, -9.93846678e-01, ...,
#                       nan,             nan,             nan],
#          [-9.93846639e-01, -9.93846674e-01, -9.93846703e-01, ...,
#                       nan,             nan,             nan],
#          ...,
#          [-9.93846882e-01, -9.93846897e-01, -9.93846912e-01, ...,
#                       nan,             nan,             nan],
#          [-9.93846894e-01, -9.93846912e-01, -9.93846927e-01, ...,
#                       nan,             nan,             nan],
#          [-9.93846910e-01, -9.93846924e-01, -9.93846941e-01, ...,
#                       nan,             nan,             nan]],
#
#         [[-9.80228734e-01, -9.80228737e-01, -9.80228744e-01, ...,
#                       nan,             nan,             nan],
#          [-9.80228754e-01, -9.80228774e-01, -9.80228793e-01, ...,
#
# kwargs:    {}
# Exception: "MemoryError((6, 1520, 1000, 80), dtype('float64'))"
#
# 2023-05-05 16:18:33,375 - distributed.worker - WARNING - Compute Failed
# Key:       ('transpose-6a2df7944d27cd5ce4bd34028b53a47c', 62, 0, 0, 0)
# Function:  subgraph_callable-f0e6aab0-ba87-4326-a232-c89389e1
# args:      (array([[[[-9.93846700e-01, -9.93846620e-01, -9.93846645e-01, ...,
#                       nan,             nan,             nan],
#          [-9.93846619e-01, -9.93846648e-01, -9.93846678e-01, ...,
#                       nan,             nan,             nan],
#          [-9.93846639e-01, -9.93846674e-01, -9.93846703e-01, ...,
#                       nan,             nan,             nan],
#          ...,
#          [-9.93846882e-01, -9.93846897e-01, -9.93846912e-01, ...,
#                       nan,             nan,             nan],
#          [-9.93846894e-01, -9.93846912e-01, -9.93846927e-01, ...,
#                       nan,             nan,             nan],
#          [-9.93846910e-01, -9.93846924e-01, -9.93846941e-01, ...,
#                       nan,             nan,             nan]],
#
#         [[-9.80228734e-01, -9.80228737e-01, -9.80228744e-01, ...,
#                       nan,             nan,             nan],
#          [-9.80228754e-01, -9.80228774e-01, -9.80228793e-01, ...,
#
# kwargs:    {}
# Exception: "MemoryError((6, 1520, 1000, 80), dtype('float64'))"
#
# 2023-05-05 16:18:33,375 - distributed.worker - WARNING - Compute Failed
# Key:       ('transpose-6a2df7944d27cd5ce4bd34028b53a47c', 94, 0, 0, 0)
# Function:  subgraph_callable-f0e6aab0-ba87-4326-a232-c89389e1
# args:      (array([[[[-9.93846700e-01, -9.93846620e-01, -9.93846645e-01, ...,
#                       nan,             nan,             nan],
#          [-9.93846619e-01, -9.93846648e-01, -9.93846678e-01, ...,
#                       nan,             nan,             nan],
#          [-9.93846639e-01, -9.93846674e-01, -9.93846703e-01, ...,
#                       nan,             nan,             nan],
#          ...,
#          [-9.93846882e-01, -9.93846897e-01, -9.93846912e-01, ...,
#                       nan,             nan,             nan],
#          [-9.93846894e-01, -9.93846912e-01, -9.93846927e-01, ...,
#                       nan,             nan,             nan],
#          [-9.93846910e-01, -9.93846924e-01, -9.93846941e-01, ...,
#                       nan,             nan,             nan]],
#
#         [[-9.80228734e-01, -9.80228737e-01, -9.80228744e-01, ...,
#                       nan,             nan,             nan],
#          [-9.80228754e-01, -9.80228774e-01, -9.80228793e-01, ...,
#
# kwargs:    {}
# Exception: "MemoryError((6, 1520, 1000, 80), dtype('float64'))"
#
# 2023-05-05 16:18:33,375 - distributed.worker - WARNING - Compute Failed
# Key:       ('transpose-6a2df7944d27cd5ce4bd34028b53a47c', 31, 0, 0, 0)
# Function:  subgraph_callable-f0e6aab0-ba87-4326-a232-c89389e1
# args:      (array([[[[-9.93846700e-01, -9.93846620e-01, -9.93846645e-01, ...,
#                       nan,             nan,             nan],
#          [-9.93846619e-01, -9.93846648e-01, -9.93846678e-01, ...,
#                       nan,             nan,             nan],
#          [-9.93846639e-01, -9.93846674e-01, -9.93846703e-01, ...,
#                       nan,             nan,             nan],
#          ...,
#          [-9.93846882e-01, -9.93846897e-01, -9.93846912e-01, ...,
#                       nan,             nan,             nan],
#          [-9.93846894e-01, -9.93846912e-01, -9.93846927e-01, ...,
#                       nan,             nan,             nan],
#          [-9.93846910e-01, -9.93846924e-01, -9.93846941e-01, ...,
#                       nan,             nan,             nan]],
#
#         [[-9.80228734e-01, -9.80228737e-01, -9.80228744e-01, ...,
#                       nan,             nan,             nan],
#          [-9.80228754e-01, -9.80228774e-01, -9.80228793e-01, ...,
#
# kwargs:    {}
# Exception: "MemoryError((6, 1520, 1000, 80), dtype('float64'))"
#
# 2023-05-05 16:18:33,377 - distributed.worker - WARNING - Compute Failed
# Key:       ('transpose-6a2df7944d27cd5ce4bd34028b53a47c', 78, 0, 0, 0)
# Function:  subgraph_callable-f0e6aab0-ba87-4326-a232-c89389e1
# args:      (array([[[[-9.93846700e-01, -9.93846620e-01, -9.93846645e-01, ...,
#                       nan,             nan,             nan],
#          [-9.93846619e-01, -9.93846648e-01, -9.93846678e-01, ...,
#                       nan,             nan,             nan],
#          [-9.93846639e-01, -9.93846674e-01, -9.93846703e-01, ...,
#                       nan,             nan,             nan],
#          ...,
#          [-9.93846882e-01, -9.93846897e-01, -9.93846912e-01, ...,
#                       nan,             nan,             nan],
#          [-9.93846894e-01, -9.93846912e-01, -9.93846927e-01, ...,
#                       nan,             nan,             nan],
#          [-9.93846910e-01, -9.93846924e-01, -9.93846941e-01, ...,
#                       nan,             nan,             nan]],
#
#         [[-9.80228734e-01, -9.80228737e-01, -9.80228744e-01, ...,
#                       nan,             nan,             nan],
#          [-9.80228754e-01, -9.80228774e-01, -9.80228793e-01, ...,
#
# kwargs:    {}
# Exception: "MemoryError((6, 1520, 1000, 80), dtype('float64'))"
#
# 2023-05-05 16:18:33,378 - distributed.worker - WARNING - Compute Failed
# Key:       ('transpose-6a2df7944d27cd5ce4bd34028b53a47c', 9, 0, 0, 0)
# Function:  subgraph_callable-f0e6aab0-ba87-4326-a232-c89389e1
# args:      (array([[[[-9.93846700e-01, -9.93846620e-01, -9.93846645e-01, ...,
#                       nan,             nan,             nan],
#          [-9.93846619e-01, -9.93846648e-01, -9.93846678e-01, ...,
#                       nan,             nan,             nan],
#          [-9.93846639e-01, -9.93846674e-01, -9.93846703e-01, ...,
#                       nan,             nan,             nan],
#          ...,
#          [-9.93846882e-01, -9.93846897e-01, -9.93846912e-01, ...,
#                       nan,             nan,             nan],
#          [-9.93846894e-01, -9.93846912e-01, -9.93846927e-01, ...,
#                       nan,             nan,             nan],
#          [-9.93846910e-01, -9.93846924e-01, -9.93846941e-01, ...,
#                       nan,             nan,             nan]],
#
#         [[-9.80228734e-01, -9.80228737e-01, -9.80228744e-01, ...,
#                       nan,             nan,             nan],
#          [-9.80228754e-01, -9.80228774e-01, -9.80228793e-01, ...,
#
# kwargs:    {}
# Exception: "MemoryError((6, 1520, 1000, 80), dtype('float64'))"
#
# 2023-05-05 16:18:33,378 - distributed.worker - WARNING - Compute Failed
# Key:       ('transpose-6a2df7944d27cd5ce4bd34028b53a47c', 114, 0, 0, 0)
# Function:  subgraph_callable-f0e6aab0-ba87-4326-a232-c89389e1
# args:      (array([[[[-9.93846700e-01, -9.93846620e-01, -9.93846645e-01, ...,
#                       nan,             nan,             nan],
#          [-9.93846619e-01, -9.93846648e-01, -9.93846678e-01, ...,
#                       nan,             nan,             nan],
#          [-9.93846639e-01, -9.93846674e-01, -9.93846703e-01, ...,
#                       nan,             nan,             nan],
#          ...,
#          [-9.93846882e-01, -9.93846897e-01, -9.93846912e-01, ...,
#                       nan,             nan,             nan],
#          [-9.93846894e-01, -9.93846912e-01, -9.93846927e-01, ...,
#                       nan,             nan,             nan],
#          [-9.93846910e-01, -9.93846924e-01, -9.93846941e-01, ...,
#                       nan,             nan,             nan]],
#
#         [[-9.80228734e-01, -9.80228737e-01, -9.80228744e-01, ...,
#                       nan,             nan,             nan],
#          [-9.80228754e-01, -9.80228774e-01, -9.80228793e-01, ...,
#
# kwargs:    {}
# Exception: "MemoryError((6, 1520, 1000, 80), dtype('float64'))"
#
# 2023-05-05 16:18:33,379 - distributed.worker - WARNING - Compute Failed
# Key:       ('transpose-6a2df7944d27cd5ce4bd34028b53a47c', 28, 0, 0, 0)
# Function:  subgraph_callable-f0e6aab0-ba87-4326-a232-c89389e1
# args:      (array([[[[-9.93846700e-01, -9.93846620e-01, -9.93846645e-01, ...,
#                       nan,             nan,             nan],
#          [-9.93846619e-01, -9.93846648e-01, -9.93846678e-01, ...,
#                       nan,             nan,             nan],
#          [-9.93846639e-01, -9.93846674e-01, -9.93846703e-01, ...,
#                       nan,             nan,             nan],
#          ...,
#          [-9.93846882e-01, -9.93846897e-01, -9.93846912e-01, ...,
#                       nan,             nan,             nan],
#          [-9.93846894e-01, -9.93846912e-01, -9.93846927e-01, ...,
#                       nan,             nan,             nan],
#          [-9.93846910e-01, -9.93846924e-01, -9.93846941e-01, ...,
#                       nan,             nan,             nan]],
#
#         [[-9.80228734e-01, -9.80228737e-01, -9.80228744e-01, ...,
#                       nan,             nan,             nan],
#          [-9.80228754e-01, -9.80228774e-01, -9.80228793e-01, ...,
#
# kwargs:    {}
# Exception: "MemoryError((6, 1520, 1000, 80), dtype('float64'))"
#
# 2023-05-05 16:18:35,751 - distributed.worker - WARNING - Compute Failed
# Key:       ('transpose-6a2df7944d27cd5ce4bd34028b53a47c', 85, 0, 0, 0)
# Function:  subgraph_callable-f0e6aab0-ba87-4326-a232-c89389e1
# args:      (array([[[[-9.93846700e-01, -9.93846620e-01, -9.93846645e-01, ...,
#                       nan,             nan,             nan],
#          [-9.93846619e-01, -9.93846648e-01, -9.93846678e-01, ...,
#                       nan,             nan,             nan],
#          [-9.93846639e-01, -9.93846674e-01, -9.93846703e-01, ...,
#                       nan,             nan,             nan],
#          ...,
#          [-9.93846882e-01, -9.93846897e-01, -9.93846912e-01, ...,
#                       nan,             nan,             nan],
#          [-9.93846894e-01, -9.93846912e-01, -9.93846927e-01, ...,
#                       nan,             nan,             nan],
#          [-9.93846910e-01, -9.93846924e-01, -9.93846941e-01, ...,
#                       nan,             nan,             nan]],
#
#         [[-9.80228734e-01, -9.80228737e-01, -9.80228744e-01, ...,
#                       nan,             nan,             nan],
#          [-9.80228754e-01, -9.80228774e-01, -9.80228793e-01, ...,
#
# kwargs:    {}
# Exception: "MemoryError((6, 1520, 1000, 80), dtype('float64'))"
#
# 2023-05-05 16:18:36,798 - distributed.worker - WARNING - Compute Failed
# Key:       ('transpose-6a2df7944d27cd5ce4bd34028b53a47c', 6, 0, 0, 0)
# Function:  subgraph_callable-f0e6aab0-ba87-4326-a232-c89389e1
# args:      (array([[[[-9.93846700e-01, -9.93846620e-01, -9.93846645e-01, ...,
#                       nan,             nan,             nan],
#          [-9.93846619e-01, -9.93846648e-01, -9.93846678e-01, ...,
#                       nan,             nan,             nan],
#          [-9.93846639e-01, -9.93846674e-01, -9.93846703e-01, ...,
#                       nan,             nan,             nan],
#          ...,
#          [-9.93846882e-01, -9.93846897e-01, -9.93846912e-01, ...,
#                       nan,             nan,             nan],
#          [-9.93846894e-01, -9.93846912e-01, -9.93846927e-01, ...,
#                       nan,             nan,             nan],
#          [-9.93846910e-01, -9.93846924e-01, -9.93846941e-01, ...,
#                       nan,             nan,             nan]],
#
#         [[-9.80228734e-01, -9.80228737e-01, -9.80228744e-01, ...,
#                       nan,             nan,             nan],
#          [-9.80228754e-01, -9.80228774e-01, -9.80228793e-01, ...,
#
# kwargs:    {}
# Exception: "MemoryError((6, 1520, 1000, 80), dtype('float64'))"
#
# 2023-05-05 16:18:36,821 - distributed.worker - WARNING - Compute Failed
# Key:       ('transpose-6a2df7944d27cd5ce4bd34028b53a47c', 72, 0, 0, 0)
# Function:  subgraph_callable-f0e6aab0-ba87-4326-a232-c89389e1
# args:      (array([[[[-9.93846700e-01, -9.93846620e-01, -9.93846645e-01, ...,
#                       nan,             nan,             nan],
#          [-9.93846619e-01, -9.93846648e-01, -9.93846678e-01, ...,
#                       nan,             nan,             nan],
#          [-9.93846639e-01, -9.93846674e-01, -9.93846703e-01, ...,
#                       nan,             nan,             nan],
#          ...,
#          [-9.93846882e-01, -9.93846897e-01, -9.93846912e-01, ...,
#                       nan,             nan,             nan],
#          [-9.93846894e-01, -9.93846912e-01, -9.93846927e-01, ...,
#                       nan,             nan,             nan],
#          [-9.93846910e-01, -9.93846924e-01, -9.93846941e-01, ...,
#                       nan,             nan,             nan]],
#
#         [[-9.80228734e-01, -9.80228737e-01, -9.80228744e-01, ...,
#                       nan,             nan,             nan],
#          [-9.80228754e-01, -9.80228774e-01, -9.80228793e-01, ...,
#
# kwargs:    {}
# Exception: "MemoryError((6, 1520, 1000, 80), dtype('float64'))"
#
# 2023-05-05 16:18:37,774 - distributed.nanny - WARNING - Worker process still alive after 3.199998474121094 seconds, killing
# 2023-05-05 16:18:37,784 - distributed.nanny - ERROR - Error in Nanny killing Worker subprocess
# Traceback (most recent call last):
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/asyncio/tasks.py", line 465, in wait_for
#     fut.result()
# asyncio.exceptions.CancelledError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/nanny.py", line 595, in close
#     await self.kill(timeout=timeout)
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/nanny.py", line 386, in kill
#     await self.process.kill(timeout=0.8 * (deadline - time()))
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/nanny.py", line 809, in kill
#     await process.join(max(0, deadline - time()))
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/process.py", line 316, in join
#     await asyncio.wait_for(asyncio.shield(self._exit_future), timeout)
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/asyncio/tasks.py", line 467, in wait_for
#     raise exceptions.TimeoutError() from exc
# asyncio.exceptions.TimeoutError
# 2023-05-05 16:18:38,705 - distributed.worker - WARNING - Compute Failed
# Key:       ('transpose-6a2df7944d27cd5ce4bd34028b53a47c', 87, 0, 0, 0)
# Function:  subgraph_callable-f0e6aab0-ba87-4326-a232-c89389e1
# args:      (array([[[[-9.93846700e-01, -9.93846620e-01, -9.93846645e-01, ...,
#                       nan,             nan,             nan],
#          [-9.93846619e-01, -9.93846648e-01, -9.93846678e-01, ...,
#                       nan,             nan,             nan],
#          [-9.93846639e-01, -9.93846674e-01, -9.93846703e-01, ...,
#                       nan,             nan,             nan],
#          ...,
#          [-9.93846882e-01, -9.93846897e-01, -9.93846912e-01, ...,
#                       nan,             nan,             nan],
#          [-9.93846894e-01, -9.93846912e-01, -9.93846927e-01, ...,
#                       nan,             nan,             nan],
#          [-9.93846910e-01, -9.93846924e-01, -9.93846941e-01, ...,
#                       nan,             nan,             nan]],
#
#         [[-9.80228734e-01, -9.80228737e-01, -9.80228744e-01, ...,
#                       nan,             nan,             nan],
#          [-9.80228754e-01, -9.80228774e-01, -9.80228793e-01, ...,
#
# kwargs:    {}
# Exception: "MemoryError((6, 1520, 1000, 80), dtype('float64'))"
#
# 2023-05-05 16:18:38,708 - distributed.worker - WARNING - Compute Failed
# Key:       ('transpose-6a2df7944d27cd5ce4bd34028b53a47c', 52, 0, 0, 0)
# Function:  subgraph_callable-f0e6aab0-ba87-4326-a232-c89389e1
# args:      (array([[[[-9.93846700e-01, -9.93846620e-01, -9.93846645e-01, ...,
#                       nan,             nan,             nan],
#          [-9.93846619e-01, -9.93846648e-01, -9.93846678e-01, ...,
#                       nan,             nan,             nan],
#          [-9.93846639e-01, -9.93846674e-01, -9.93846703e-01, ...,
#                       nan,             nan,             nan],
#          ...,
#          [-9.93846882e-01, -9.93846897e-01, -9.93846912e-01, ...,
#                       nan,             nan,             nan],
#          [-9.93846894e-01, -9.93846912e-01, -9.93846927e-01, ...,
#                       nan,             nan,             nan],
#          [-9.93846910e-01, -9.93846924e-01, -9.93846941e-01, ...,
#                       nan,             nan,             nan]],
#
#         [[-9.80228734e-01, -9.80228737e-01, -9.80228744e-01, ...,
#                       nan,             nan,             nan],
#          [-9.80228754e-01, -9.80228774e-01, -9.80228793e-01, ...,
#
# kwargs:    {}
# Exception: "MemoryError((6, 1520, 1000, 80), dtype('float64'))"
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# File <timed exec>:2
#
# File ~/miniconda3/envs/XROMS/lib/python3.8/site-packages/xrft/xrft.py:1128, in isotropic_power_spectrum(da, spacing_tol, dim, shift, detrend, scaling, window, window_correction, nfactor, truncate, **kwargs)
#    1114 ps = power_spectrum(
#    1115     da,
#    1116     spacing_tol=spacing_tol,
#    (...)
#    1123     **kwargs,
#    1124 )
#    1126 fftdim = ["freq_" + d for d in dim]
# -> 1128 return isotropize(ps, fftdim, nfactor=nfactor, truncate=truncate)
#
# File ~/miniconda3/envs/XROMS/lib/python3.8/site-packages/xrft/xrft.py:1041, in isotropize(ps, fftdim, nfactor, truncate, complx)
#    1039 iso_ps.coords["freq_r"] = kr.data
#    1040 if truncate:
# -> 1041     return (iso_ps * iso_ps.freq_r).dropna("freq_r")
#    1042 else:
#    1043     return iso_ps * iso_ps.freq_r
#
# File ~/miniconda3/envs/XROMS/lib/python3.8/site-packages/xarray/core/dataarray.py:2651, in DataArray.dropna(self, dim, how, thresh)
#    2626 def dropna(
#    2627     self: T_DataArray,
#    2628     dim: Hashable,
#    2629     how: Literal["any", "all"] = "any",
#    2630     thresh: int | None = None,
#    2631 ) -> T_DataArray:
#    2632     """Returns a new array with dropped labels for missing values along
#    2633     the provided dimension.
#    2634
#    (...)
#    2649     dropped : DataArray
#    2650     """
# -> 2651     ds = self._to_temp_dataset().dropna(dim, how=how, thresh=thresh)
#    2652     return self._from_temp_dataset(ds)
#
# File ~/miniconda3/envs/XROMS/lib/python3.8/site-packages/xarray/core/dataset.py:5190, in Dataset.dropna(self, dim, how, thresh, subset)
#    5188     if dim in array.dims:
#    5189         dims = [d for d in array.dims if d != dim]
# -> 5190         count += np.asarray(array.count(dims))  # type: ignore[attr-defined]
#    5191         size += math.prod([self.dims[d] for d in dims])
#    5193 if thresh is not None:
#
# File ~/miniconda3/envs/XROMS/lib/python3.8/site-packages/xarray/core/common.py:156, in AbstractArray.__array__(self, dtype)
#     155 def __array__(self: Any, dtype: DTypeLike = None) -> np.ndarray:
# --> 156     return np.asarray(self.values, dtype=dtype)
#
# File ~/miniconda3/envs/XROMS/lib/python3.8/site-packages/xarray/core/variable.py:527, in Variable.values(self)
#     524 @property
#     525 def values(self):
#     526     """The variable's data as a numpy.ndarray"""
# --> 527     return _as_array_or_item(self._data)
#
# File ~/miniconda3/envs/XROMS/lib/python3.8/site-packages/xarray/core/variable.py:267, in _as_array_or_item(data)
#     253 def _as_array_or_item(data):
#     254     """Return the given values as a numpy array, or as an individual item if
#     255     it's a 0d datetime64 or timedelta64 array.
#     256
#    (...)
#     265     TODO: remove this (replace with np.asarray) once these issues are fixed
#     266     """
# --> 267     data = np.asarray(data)
#     268     if data.ndim == 0:
#     269         if data.dtype.kind == "M":
#
# File ~/miniconda3/envs/XROMS/lib/python3.8/site-packages/dask/array/core.py:1696, in Array.__array__(self, dtype, **kwargs)
#    1695 def __array__(self, dtype=None, **kwargs):
# -> 1696     x = self.compute()
#    1697     if dtype and x.dtype != dtype:
#    1698         x = x.astype(dtype)
#
# File ~/miniconda3/envs/XROMS/lib/python3.8/site-packages/dask/base.py:315, in DaskMethodsMixin.compute(self, **kwargs)
#     291 def compute(self, **kwargs):
#     292     """Compute this dask collection
#     293
#     294     This turns a lazy Dask collection into its in-memory equivalent.
#    (...)
#     313     dask.base.compute
#     314     """
# --> 315     (result,) = compute(self, traverse=False, **kwargs)
#     316     return result
#
# File ~/miniconda3/envs/XROMS/lib/python3.8/site-packages/dask/base.py:600, in compute(traverse, optimize_graph, scheduler, get, *args, **kwargs)
#     597     keys.append(x.__dask_keys__())
#     598     postcomputes.append(x.__dask_postcompute__())
# --> 600 results = schedule(dsk, keys, **kwargs)
#     601 return repack([f(r, *a) for r, (f, a) in zip(results, postcomputes)])
#
# File ~/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/client.py:3052, in Client.get(self, dsk, keys, workers, allow_other_workers, resources, sync, asynchronous, direct, retries, priority, fifo_timeout, actors, **kwargs)
#    3050         should_rejoin = False
#    3051 try:
# -> 3052     results = self.gather(packed, asynchronous=asynchronous, direct=direct)
#    3053 finally:
#    3054     for f in futures.values():
#
# File ~/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/client.py:2226, in Client.gather(self, futures, errors, direct, asynchronous)
#    2224 else:
#    2225     local_worker = None
# -> 2226 return self.sync(
#    2227     self._gather,
#    2228     futures,
#    2229     errors=errors,
#    2230     direct=direct,
#    2231     local_worker=local_worker,
#    2232     asynchronous=asynchronous,
#    2233 )
#
# File ~/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/utils.py:338, in SyncMethodMixin.sync(self, func, asynchronous, callback_timeout, *args, **kwargs)
#     336     return future
#     337 else:
# --> 338     return sync(
#     339         self.loop, func, *args, callback_timeout=callback_timeout, **kwargs
#     340     )
#
# File ~/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/utils.py:405, in sync(loop, func, callback_timeout, *args, **kwargs)
#     403 if error:
#     404     typ, exc, tb = error
# --> 405     raise exc.with_traceback(tb)
#     406 else:
#     407     return result
#
# File ~/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/utils.py:378, in sync.<locals>.f()
#     376         future = asyncio.wait_for(future, callback_timeout)
#     377     future = asyncio.ensure_future(future)
# --> 378     result = yield future
#     379 except Exception:
#     380     error = sys.exc_info()
#
# File ~/miniconda3/envs/XROMS/lib/python3.8/site-packages/tornado/gen.py:762, in Runner.run(self)
#     759 exc_info = None
#     761 try:
# --> 762     value = future.result()
#     763 except Exception:
#     764     exc_info = sys.exc_info()
#
# File ~/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/client.py:2089, in Client._gather(self, futures, errors, direct, local_worker)
#    2087         exc = CancelledError(key)
#    2088     else:
# -> 2089         raise exception.with_traceback(traceback)
#    2090     raise exc
#    2091 if errors == "skip":
#
# File ~/miniconda3/envs/XROMS/lib/python3.8/site-packages/dask/optimization.py:990, in __call__()
#     988 if not len(args) == len(self.inkeys):
#     989     raise ValueError("Expected %d args, got %d" % (len(self.inkeys), len(args)))
# --> 990 return core.get(self.dsk, self.outkey, dict(zip(self.inkeys, args)))
#
# File ~/miniconda3/envs/XROMS/lib/python3.8/site-packages/dask/core.py:149, in get()
#     147 for key in toposort(dsk):
#     148     task = dsk[key]
# --> 149     result = _execute_task(task, cache)
#     150     cache[key] = result
#     151 result = _execute_task(out, cache)
#
# File ~/miniconda3/envs/XROMS/lib/python3.8/site-packages/dask/core.py:119, in _execute_task()
#     115     func, args = arg[0], arg[1:]
#     116     # Note: Don't assign the subtask results to a variable. numpy detects
#     117     # temporaries by their reference count and can execute certain
#     118     # operations in-place.
# --> 119     return func(*(_execute_task(a, cache) for a in args))
#     120 elif not ishashable(arg):
#     121     return arg
#
# File ~/miniconda3/envs/XROMS/lib/python3.8/site-packages/dask/core.py:119, in <genexpr>()
#     115     func, args = arg[0], arg[1:]
#     116     # Note: Don't assign the subtask results to a variable. numpy detects
#     117     # temporaries by their reference count and can execute certain
#     118     # operations in-place.
# --> 119     return func(*(_execute_task(a, cache) for a in args))
#     120 elif not ishashable(arg):
#     121     return arg
#
# File ~/miniconda3/envs/XROMS/lib/python3.8/site-packages/dask/core.py:113, in _execute_task()
#      83 """Do the actual work of collecting data and executing a function
#      84
#      85 Examples
#    (...)
#     110 'foo'
#     111 """
#     112 if isinstance(arg, list):
# --> 113     return [_execute_task(a, cache) for a in arg]
#     114 elif istask(arg):
#     115     func, args = arg[0], arg[1:]
#
# File ~/miniconda3/envs/XROMS/lib/python3.8/site-packages/dask/core.py:113, in <listcomp>()
#      83 """Do the actual work of collecting data and executing a function
#      84
#      85 Examples
#    (...)
#     110 'foo'
#     111 """
#     112 if isinstance(arg, list):
# --> 113     return [_execute_task(a, cache) for a in arg]
#     114 elif istask(arg):
#     115     func, args = arg[0], arg[1:]
#
# File ~/miniconda3/envs/XROMS/lib/python3.8/site-packages/dask/core.py:119, in _execute_task()
#     115     func, args = arg[0], arg[1:]
#     116     # Note: Don't assign the subtask results to a variable. numpy detects
#     117     # temporaries by their reference count and can execute certain
#     118     # operations in-place.
# --> 119     return func(*(_execute_task(a, cache) for a in args))
#     120 elif not ishashable(arg):
#     121     return arg
#
# MemoryError: Unable to allocate 5.44 GiB for an array with shape (6, 1520, 1000, 80) and data type float64

# %%
# %%time

with ProgressBar():
    Vf=xrft.isotropic_power_spectrum(v_full_interp,
                                      dim=['eta_v','xi_u'],
                              nfactor=nf,truncate='True',scaling=scl,detrend='linear', 
                                     window=wdws,window_correction=wdw_cor)
# Out:
# 2023-05-05 16:18:44,351 - distributed.worker - ERROR - Exception during execution of task ('transpose-6a2df7944d27cd5ce4bd34028b53a47c', 56, 0, 0, 0).
# Traceback (most recent call last):
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/worker.py", line 2302, in _prepare_args_for_execution
#     data[k] = self.data[k]
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/zict/buffer.py", line 108, in __getitem__
#     raise KeyError(key)
# KeyError: "('getitem-a2e0ccd4e11d42d37756f29804b009ec', 0, 56, 0, 0)"
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/worker.py", line 2200, in execute
#     args2, kwargs2 = self._prepare_args_for_execution(ts, args, kwargs)
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/worker.py", line 2306, in _prepare_args_for_execution
#     data[k] = Actor(type(self.state.actors[k]), self.address, k, self)
# KeyError: "('getitem-a2e0ccd4e11d42d37756f29804b009ec', 0, 56, 0, 0)"
# 2023-05-05 16:18:47,477 - distributed.worker - ERROR - Exception during execution of task ('getitem-a2e0ccd4e11d42d37756f29804b009ec', 0, 83, 0, 0).
# Traceback (most recent call last):
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/worker.py", line 2302, in _prepare_args_for_execution
#     data[k] = self.data[k]
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/zict/buffer.py", line 108, in __getitem__
#     raise KeyError(key)
# KeyError: "('add-getitem-a2e0ccd4e11d42d37756f29804b009ec', 0, 83, 0, 0)"
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/worker.py", line 2200, in execute
#     args2, kwargs2 = self._prepare_args_for_execution(ts, args, kwargs)
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/worker.py", line 2306, in _prepare_args_for_execution
#     data[k] = Actor(type(self.state.actors[k]), self.address, k, self)
# KeyError: "('add-getitem-a2e0ccd4e11d42d37756f29804b009ec', 0, 83, 0, 0)"
# 2023-05-05 16:18:47,666 - distributed.worker - WARNING - Compute Failed
# Key:       ('transpose-6a2df7944d27cd5ce4bd34028b53a47c', 37, 0, 0, 0)
# Function:  subgraph_callable-f0e6aab0-ba87-4326-a232-c89389e1
# args:      (array([[[[-9.93846700e-01, -9.93846620e-01, -9.93846645e-01, ...,
#                       nan,             nan,             nan],
#          [-9.93846619e-01, -9.93846648e-01, -9.93846678e-01, ...,
#                       nan,             nan,             nan],
#          [-9.93846639e-01, -9.93846674e-01, -9.93846703e-01, ...,
#                       nan,             nan,             nan],
#          ...,
#          [-9.93846882e-01, -9.93846897e-01, -9.93846912e-01, ...,
#                       nan,             nan,             nan],
#          [-9.93846894e-01, -9.93846912e-01, -9.93846927e-01, ...,
#                       nan,             nan,             nan],
#          [-9.93846910e-01, -9.93846924e-01, -9.93846941e-01, ...,
#                       nan,             nan,             nan]],
#
#         [[-9.80228734e-01, -9.80228737e-01, -9.80228744e-01, ...,
#                       nan,             nan,             nan],
#          [-9.80228754e-01, -9.80228774e-01, -9.80228793e-01, ...,
#
# kwargs:    {}
# Exception: "MemoryError((6, 1520, 1000, 80), dtype('float64'))"
#
# 2023-05-05 16:18:48,396 - distributed.worker - WARNING - Compute Failed
# Key:       ('mul-ec29465333471623f11fde2b38659547', 5, 0, 0, 0)
# Function:  subgraph_callable-262ef19e-2be3-481d-b2a9-ddc577a6
# args:      (0.5, array([[[[-4.41653822e+03, -4.41702945e+03, -4.41752197e+03, ...,
#                       nan,             nan,             nan],
#          [-4.41821158e+03, -4.41870718e+03, -4.41920263e+03, ...,
#                       nan,             nan,             nan],
#          [-4.41988340e+03, -4.42038241e+03, -4.42087834e+03, ...,
#                       nan,             nan,             nan],
#          ...,
#          [-4.71092701e+03, -4.71038745e+03, -4.70984730e+03, ...,
#                       nan,             nan,             nan],
#          [-4.71211976e+03, -4.71158167e+03, -4.71104247e+03, ...,
#                       nan,             nan,             nan],
#          [-4.71331555e+03, -4.71277502e+03, -4.71223680e+03, ...,
#                       nan,             nan,             nan]],
#
#         [[-4.35602276e+03, -4.35650762e+03, -4.35699331e+03, ...,
#                       nan,             nan,             nan],
#          [-4.35767364e+03, -4.35816240e+03, -4.35865102e+03, ...,
#
# kwargs:    {}
# Exception: "MemoryError((6, 80, 1520, 999), dtype('float64'))"
#
# 2023-05-05 16:18:48,398 - distributed.worker - WARNING - Compute Failed
# Key:       ('mul-ec29465333471623f11fde2b38659547', 38, 0, 0, 0)
# Function:  subgraph_callable-262ef19e-2be3-481d-b2a9-ddc577a6
# args:      (0.5, array([[[[-4.41653878e+03, -4.41703001e+03, -4.41752260e+03, ...,
#                       nan,             nan,             nan],
#          [-4.41821214e+03, -4.41870774e+03, -4.41920325e+03, ...,
#                       nan,             nan,             nan],
#          [-4.41988375e+03, -4.42038277e+03, -4.42087869e+03, ...,
#                       nan,             nan,             nan],
#          ...,
#          [-4.71092764e+03, -4.71038809e+03, -4.70984840e+03, ...,
#                       nan,             nan,             nan],
#          [-4.71212079e+03, -4.71158271e+03, -4.71104301e+03, ...,
#                       nan,             nan,             nan],
#          [-4.71331659e+03, -4.71277606e+03, -4.71223735e+03, ...,
#                       nan,             nan,             nan]],
#
#         [[-4.35602423e+03, -4.35650909e+03, -4.35699485e+03, ...,
#                       nan,             nan,             nan],
#          [-4.35767511e+03, -4.35816387e+03, -4.35865255e+03, ...,
#
# kwargs:    {}
# Exception: "MemoryError((6, 80, 1520, 999), dtype('float64'))"
#
# 2023-05-05 16:18:50,499 - distributed.worker - ERROR - Worker stream died during communication: tcp://127.0.0.1:45631
# Traceback (most recent call last):
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nbytes = await stream.read_bytes(fmt_size)
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/worker.py", line 2016, in gather_dep
#     response = await get_data_from_worker(
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/worker.py", line 2805, in get_data_from_worker
#     return await retry_operation(_get_data, operation="get_data_from_worker")
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/utils_comm.py", line 383, in retry_operation
#     return await retry(
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/utils_comm.py", line 368, in retry
#     return await coro()
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/worker.py", line 2785, in _get_data
#     response = await send_recv(
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/core.py", line 919, in send_recv
#     response = await comm.read(deserializers=deserializers)
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/comm/tcp.py", line 241, in read
#     convert_stream_closed_error(self, e)
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/comm/tcp.py", line 144, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) Ephemeral Worker->Worker for gather local=tcp://127.0.0.1:39492 remote=tcp://127.0.0.1:45631>: Stream is closed
# 2023-05-05 16:18:50,499 - distributed.worker - ERROR - Worker stream died during communication: tcp://127.0.0.1:45631
# Traceback (most recent call last):
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/comm/tcp.py", line 235, in read
#     n = await stream.read_into(chunk)
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/worker.py", line 2016, in gather_dep
#     response = await get_data_from_worker(
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/worker.py", line 2805, in get_data_from_worker
#     return await retry_operation(_get_data, operation="get_data_from_worker")
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/utils_comm.py", line 383, in retry_operation
#     return await retry(
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/utils_comm.py", line 368, in retry
#     return await coro()
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/worker.py", line 2785, in _get_data
#     response = await send_recv(
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/core.py", line 919, in send_recv
#     response = await comm.read(deserializers=deserializers)
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/comm/tcp.py", line 241, in read
#     convert_stream_closed_error(self, e)
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/comm/tcp.py", line 144, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) Ephemeral Worker->Worker for gather local=tcp://127.0.0.1:39442 remote=tcp://127.0.0.1:45631>: Stream is closed
# 2023-05-05 16:18:50,499 - distributed.worker - ERROR - Worker stream died during communication: tcp://127.0.0.1:45631
# Traceback (most recent call last):
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/comm/tcp.py", line 235, in read
#     n = await stream.read_into(chunk)
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/worker.py", line 2016, in gather_dep
#     response = await get_data_from_worker(
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/worker.py", line 2805, in get_data_from_worker
#     return await retry_operation(_get_data, operation="get_data_from_worker")
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/utils_comm.py", line 383, in retry_operation
#     return await retry(
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/utils_comm.py", line 368, in retry
#     return await coro()
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/worker.py", line 2785, in _get_data
#     response = await send_recv(
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/core.py", line 919, in send_recv
#     response = await comm.read(deserializers=deserializers)
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/comm/tcp.py", line 241, in read
#     convert_stream_closed_error(self, e)
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/comm/tcp.py", line 144, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) Ephemeral Worker->Worker for gather local=tcp://127.0.0.1:39462 remote=tcp://127.0.0.1:45631>: Stream is closed
# 2023-05-05 16:18:50,499 - distributed.worker - ERROR - Worker stream died during communication: tcp://127.0.0.1:45631
# Traceback (most recent call last):
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/comm/tcp.py", line 235, in read
#     n = await stream.read_into(chunk)
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/worker.py", line 2016, in gather_dep
#     response = await get_data_from_worker(
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/worker.py", line 2805, in get_data_from_worker
#     return await retry_operation(_get_data, operation="get_data_from_worker")
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/utils_comm.py", line 383, in retry_operation
#     return await retry(
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/utils_comm.py", line 368, in retry
#     return await coro()
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/worker.py", line 2785, in _get_data
#     response = await send_recv(
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/core.py", line 919, in send_recv
#     response = await comm.read(deserializers=deserializers)
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/comm/tcp.py", line 241, in read
#     convert_stream_closed_error(self, e)
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/comm/tcp.py", line 144, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) Ephemeral Worker->Worker for gather local=tcp://127.0.0.1:39478 remote=tcp://127.0.0.1:45631>: Stream is closed
# 2023-05-05 16:18:50,607 - distributed.nanny - WARNING - Restarting worker
# 2023-05-05 16:18:51,028 - distributed.worker - WARNING - Compute Failed
# Key:       ('transpose-6a2df7944d27cd5ce4bd34028b53a47c', 2, 0, 0, 0)
# Function:  subgraph_callable-f0e6aab0-ba87-4326-a232-c89389e1
# args:      (array([[[[-9.93846700e-01, -9.93846620e-01, -9.93846645e-01, ...,
#                       nan,             nan,             nan],
#          [-9.93846619e-01, -9.93846648e-01, -9.93846678e-01, ...,
#                       nan,             nan,             nan],
#          [-9.93846639e-01, -9.93846674e-01, -9.93846703e-01, ...,
#                       nan,             nan,             nan],
#          ...,
#          [-9.93846882e-01, -9.93846897e-01, -9.93846912e-01, ...,
#                       nan,             nan,             nan],
#          [-9.93846894e-01, -9.93846912e-01, -9.93846927e-01, ...,
#                       nan,             nan,             nan],
#          [-9.93846910e-01, -9.93846924e-01, -9.93846941e-01, ...,
#                       nan,             nan,             nan]],
#
#         [[-9.80228734e-01, -9.80228737e-01, -9.80228744e-01, ...,
#                       nan,             nan,             nan],
#          [-9.80228754e-01, -9.80228774e-01, -9.80228793e-01, ...,
#
# kwargs:    {}
# Exception: "MemoryError((6, 1520, 1000, 80), dtype('float64'))"
#
# 2023-05-05 16:18:51,030 - distributed.worker - WARNING - Compute Failed
# Key:       ('transpose-6a2df7944d27cd5ce4bd34028b53a47c', 69, 0, 0, 0)
# Function:  subgraph_callable-f0e6aab0-ba87-4326-a232-c89389e1
# args:      (array([[[[-9.93846700e-01, -9.93846620e-01, -9.93846645e-01, ...,
#                       nan,             nan,             nan],
#          [-9.93846619e-01, -9.93846648e-01, -9.93846678e-01, ...,
#                       nan,             nan,             nan],
#          [-9.93846639e-01, -9.93846674e-01, -9.93846703e-01, ...,
#                       nan,             nan,             nan],
#          ...,
#          [-9.93846882e-01, -9.93846897e-01, -9.93846912e-01, ...,
#                       nan,             nan,             nan],
#          [-9.93846894e-01, -9.93846912e-01, -9.93846927e-01, ...,
#                       nan,             nan,             nan],
#          [-9.93846910e-01, -9.93846924e-01, -9.93846941e-01, ...,
#                       nan,             nan,             nan]],
#
#         [[-9.80228734e-01, -9.80228737e-01, -9.80228744e-01, ...,
#                       nan,             nan,             nan],
#          [-9.80228754e-01, -9.80228774e-01, -9.80228793e-01, ...,
#
# kwargs:    {}
# Exception: "MemoryError((6, 1520, 1000, 80), dtype('float64'))"
#
# 2023-05-05 16:18:51,334 - distributed.worker - WARNING - Compute Failed
# Key:       ('transpose-6a2df7944d27cd5ce4bd34028b53a47c', 30, 0, 0, 0)
# Function:  subgraph_callable-f0e6aab0-ba87-4326-a232-c89389e1
# args:      (array([[[[-9.93846700e-01, -9.93846620e-01, -9.93846645e-01, ...,
#                       nan,             nan,             nan],
#          [-9.93846619e-01, -9.93846648e-01, -9.93846678e-01, ...,
#                       nan,             nan,             nan],
#          [-9.93846639e-01, -9.93846674e-01, -9.93846703e-01, ...,
#                       nan,             nan,             nan],
#          ...,
#          [-9.93846882e-01, -9.93846897e-01, -9.93846912e-01, ...,
#                       nan,             nan,             nan],
#          [-9.93846894e-01, -9.93846912e-01, -9.93846927e-01, ...,
#                       nan,             nan,             nan],
#          [-9.93846910e-01, -9.93846924e-01, -9.93846941e-01, ...,
#                       nan,             nan,             nan]],
#
#         [[-9.80228734e-01, -9.80228737e-01, -9.80228744e-01, ...,
#                       nan,             nan,             nan],
#          [-9.80228754e-01, -9.80228774e-01, -9.80228793e-01, ...,
#
# kwargs:    {}
# Exception: "MemoryError((6, 1520, 1000, 80), dtype('float64'))"
#
# 2023-05-05 16:18:51,832 - distributed.worker - WARNING - Compute Failed
# Key:       ('transpose-6a2df7944d27cd5ce4bd34028b53a47c', 112, 0, 0, 0)
# Function:  subgraph_callable-f0e6aab0-ba87-4326-a232-c89389e1
# args:      (array([[[[-9.93846700e-01, -9.93846620e-01, -9.93846645e-01, ...,
#                       nan,             nan,             nan],
#          [-9.93846619e-01, -9.93846648e-01, -9.93846678e-01, ...,
#                       nan,             nan,             nan],
#          [-9.93846639e-01, -9.93846674e-01, -9.93846703e-01, ...,
#                       nan,             nan,             nan],
#          ...,
#          [-9.93846882e-01, -9.93846897e-01, -9.93846912e-01, ...,
#                       nan,             nan,             nan],
#          [-9.93846894e-01, -9.93846912e-01, -9.93846927e-01, ...,
#                       nan,             nan,             nan],
#          [-9.93846910e-01, -9.93846924e-01, -9.93846941e-01, ...,
#                       nan,             nan,             nan]],
#
#         [[-9.80228734e-01, -9.80228737e-01, -9.80228744e-01, ...,
#                       nan,             nan,             nan],
#          [-9.80228754e-01, -9.80228774e-01, -9.80228793e-01, ...,
#
# kwargs:    {}
# Exception: "MemoryError((6, 1520, 1000, 80), dtype('float64'))"
#
# 2023-05-05 16:18:55,379 - distributed.worker - WARNING - Compute Failed
# Key:       ('transpose-6a2df7944d27cd5ce4bd34028b53a47c', 92, 0, 0, 0)
# Function:  subgraph_callable-f0e6aab0-ba87-4326-a232-c89389e1
# args:      (array([[[[-9.93846700e-01, -9.93846620e-01, -9.93846645e-01, ...,
#                       nan,             nan,             nan],
#          [-9.93846619e-01, -9.93846648e-01, -9.93846678e-01, ...,
#                       nan,             nan,             nan],
#          [-9.93846639e-01, -9.93846674e-01, -9.93846703e-01, ...,
#                       nan,             nan,             nan],
#          ...,
#          [-9.93846882e-01, -9.93846897e-01, -9.93846912e-01, ...,
#                       nan,             nan,             nan],
#          [-9.93846894e-01, -9.93846912e-01, -9.93846927e-01, ...,
#                       nan,             nan,             nan],
#          [-9.93846910e-01, -9.93846924e-01, -9.93846941e-01, ...,
#                       nan,             nan,             nan]],
#
#         [[-9.80228734e-01, -9.80228737e-01, -9.80228744e-01, ...,
#                       nan,             nan,             nan],
#          [-9.80228754e-01, -9.80228774e-01, -9.80228793e-01, ...,
#
# kwargs:    {}
# Exception: "MemoryError((6, 1520, 1000, 80), dtype('float64'))"
#
# 2023-05-05 16:19:08,809 - distributed.nanny - WARNING - Worker process still alive after 3.1999992370605472 seconds, killing
# 2023-05-05 16:19:14,085 - distributed.worker - ERROR - failed during get data with tcp://127.0.0.1:44539 -> tcp://127.0.0.1:46795
# Traceback (most recent call last):
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/tornado/iostream.py", line 867, in _read_to_buffer
#     bytes_read = self.read_from_fd(buf)
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/tornado/iostream.py", line 1140, in read_from_fd
#     return self.socket.recv_into(buf, len(buf))
# TimeoutError: [Errno 110] Connection timed out
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/worker.py", line 1723, in get_data
#     response = await comm.read(deserializers=serializers)
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/comm/tcp.py", line 241, in read
#     convert_stream_closed_error(self, e)
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/comm/tcp.py", line 142, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc.__class__.__name__}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed)  local=tcp://127.0.0.1:44539 remote=tcp://127.0.0.1:59430>: TimeoutError: [Errno 110] Connection timed out
# 2023-05-05 16:19:32,010 - distributed.nanny - ERROR - Worker process died unexpectedly
# 2023-05-05 16:19:32,010 - distributed.nanny - ERROR - Worker process died unexpectedly
# 2023-05-05 16:19:32,011 - distributed.nanny - ERROR - Worker process died unexpectedly
# 2023-05-05 16:19:32,011 - distributed.nanny - ERROR - Worker process died unexpectedly
# 2023-05-05 16:19:32,011 - distributed.nanny - ERROR - Worker process died unexpectedly
# 2023-05-05 16:19:32,011 - distributed.nanny - ERROR - Worker process died unexpectedly
# 2023-05-05 16:19:32,011 - distributed.nanny - ERROR - Worker process died unexpectedly
# 2023-05-05 16:19:32,011 - distributed.nanny - ERROR - Worker process died unexpectedly
# 2023-05-05 16:19:32,011 - distributed.nanny - ERROR - Worker process died unexpectedly
# 2023-05-05 16:19:32,011 - distributed.nanny - ERROR - Worker process died unexpectedly
# 2023-05-05 16:19:32,011 - distributed.nanny - ERROR - Worker process died unexpectedly
# 2023-05-05 16:19:32,011 - distributed.nanny - ERROR - Worker process died unexpectedly
# 2023-05-05 16:19:32,011 - distributed.nanny - ERROR - Worker process died unexpectedly
# 2023-05-05 16:19:32,012 - distributed.nanny - ERROR - Worker process died unexpectedly
# 2023-05-05 16:19:32,012 - distributed.nanny - ERROR - Worker process died unexpectedly
# 2023-05-05 16:19:32,012 - distributed.nanny - ERROR - Worker process died unexpectedly
# 2023-05-05 16:19:32,012 - distributed.nanny - ERROR - Worker process died unexpectedly
# 2023-05-05 16:19:32,012 - distributed.nanny - ERROR - Worker process died unexpectedly
# 2023-05-05 16:19:32,012 - distributed.nanny - ERROR - Worker process died unexpectedly
# 2023-05-05 16:19:32,012 - distributed.nanny - ERROR - Worker process died unexpectedly
# 2023-05-05 16:19:32,012 - distributed.nanny - ERROR - Worker process died unexpectedly
# 2023-05-05 16:19:32,012 - distributed.nanny - ERROR - Worker process died unexpectedly
# 2023-05-05 16:19:32,012 - distributed.nanny - ERROR - Worker process died unexpectedly
# 2023-05-05 16:19:32,012 - distributed.nanny - ERROR - Worker process died unexpectedly
# 2023-05-05 16:19:32,012 - distributed.nanny - ERROR - Worker process died unexpectedly
# 2023-05-05 16:19:32,012 - distributed.nanny - ERROR - Worker process died unexpectedly
# 2023-05-05 16:19:32,012 - distributed.nanny - ERROR - Worker process died unexpectedly
# 2023-05-05 16:19:32,013 - distributed.nanny - ERROR - Worker process died unexpectedly
# 2023-05-05 16:19:32,013 - distributed.nanny - ERROR - Worker process died unexpectedly
# 2023-05-05 16:19:32,013 - distributed.nanny - ERROR - Worker process died unexpectedly
# 2023-05-05 16:19:32,013 - distributed.nanny - ERROR - Worker process died unexpectedly
# 2023-05-05 16:19:32,013 - distributed.nanny - ERROR - Worker process died unexpectedly
# 2023-05-05 16:19:32,013 - distributed.nanny - ERROR - Worker process died unexpectedly
# 2023-05-05 16:19:32,013 - distributed.nanny - ERROR - Worker process died unexpectedly
# 2023-05-05 16:19:32,013 - distributed.nanny - ERROR - Worker process died unexpectedly
# 2023-05-05 16:19:32,013 - distributed.nanny - ERROR - Worker process died unexpectedly
# 2023-05-05 16:19:32,014 - distributed.nanny - ERROR - Worker process died unexpectedly
# 2023-05-05 16:19:32,014 - distributed.nanny - ERROR - Worker process died unexpectedly
# 2023-05-05 16:19:32,014 - distributed.nanny - ERROR - Worker process died unexpectedly
# 2023-05-05 16:19:32,014 - distributed.nanny - ERROR - Worker process died unexpectedly
# 2023-05-05 16:19:32,011 - distributed.worker - WARNING - Heartbeat to scheduler failed
# Traceback (most recent call last):
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nbytes = await stream.read_bytes(fmt_size)
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/worker.py", line 1178, in heartbeat
#     response = await retry_operation(
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/utils_comm.py", line 383, in retry_operation
#     return await retry(
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/utils_comm.py", line 368, in retry
#     return await coro()
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/core.py", line 1154, in send_recv_from_rpc
#     return await send_recv(comm=comm, op=key, **kwargs)
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/core.py", line 919, in send_recv
#     response = await comm.read(deserializers=deserializers)
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/comm/tcp.py", line 241, in read
#     convert_stream_closed_error(self, e)
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/comm/tcp.py", line 144, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) ConnectionPool.heartbeat_worker local=tcp://127.0.0.1:43608 remote=tcp://127.0.0.1:41596>: Stream is closed
# 2023-05-05 16:19:32,012 - distributed.worker - WARNING - Heartbeat to scheduler failed
# Traceback (most recent call last):
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nbytes = await stream.read_bytes(fmt_size)
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/worker.py", line 1178, in heartbeat
#     response = await retry_operation(
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/utils_comm.py", line 383, in retry_operation
#     return await retry(
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/utils_comm.py", line 368, in retry
#     return await coro()
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/core.py", line 1154, in send_recv_from_rpc
#     return await send_recv(comm=comm, op=key, **kwargs)
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/core.py", line 919, in send_recv
#     response = await comm.read(deserializers=deserializers)
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/comm/tcp.py", line 241, in read
#     convert_stream_closed_error(self, e)
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/comm/tcp.py", line 144, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) ConnectionPool.heartbeat_worker local=tcp://127.0.0.1:43620 remote=tcp://127.0.0.1:41596>: Stream is closed
# 2023-05-05 16:19:32,011 - distributed.worker - WARNING - Heartbeat to scheduler failed
# Traceback (most recent call last):
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nbytes = await stream.read_bytes(fmt_size)
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/worker.py", line 1178, in heartbeat
#     response = await retry_operation(
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/utils_comm.py", line 383, in retry_operation
#     return await retry(
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/u
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File <timed exec>:2
#
# File ~/miniconda3/envs/XROMS/lib/python3.8/site-packages/xrft/xrft.py:1128, in isotropic_power_spectrum(da, spacing_tol, dim, shift, detrend, scaling, window, window_correction, nfactor, truncate, **kwargs)
#    1114 ps = power_spectrum(
#    1115     da,
#    1116     spacing_tol=spacing_tol,
#    (...)
#    1123     **kwargs,
#    1124 )
#    1126 fftdim = ["freq_" + d for d in dim]
# -> 1128 return isotropize(ps, fftdim, nfactor=nfactor, truncate=truncate)
#
# File ~/miniconda3/envs/XROMS/lib/python3.8/site-packages/xrft/xrft.py:1041, in isotropize(ps, fftdim, nfactor, truncate, complx)
#    1039 iso_ps.coords["freq_r"] = kr.data
#    1040 if truncate:
# -> 1041     return (iso_ps * iso_ps.freq_r).dropna("freq_r")
#    1042 else:
#    1043     return iso_ps * iso_ps.freq_r
#
# File ~/miniconda3/envs/XROMS/lib/python3.8/site-packages/xarray/core/dataarray.py:2651, in DataArray.dropna(self, dim, how, thresh)
#    2626 def dropna(
#    2627     self: T_DataArray,
#    2628     dim: Hashable,
#    2629     how: Literal["any", "all"] = "any",
#    2630     thresh: int | None = None,
#    2631 ) -> T_DataArray:
#    2632     """Returns a new array with dropped labels for missing values along
#    2633     the provided dimension.
#    2634
#    (...)
#    2649     dropped : DataArray
#    2650     """
# -> 2651     ds = self._to_temp_dataset().dropna(dim, how=how, thresh=thresh)
#    2652     return self._from_temp_dataset(ds)
#
# File ~/miniconda3/envs/XROMS/lib/python3.8/site-packages/xarray/core/dataset.py:5190, in Dataset.dropna(self, dim, how, thresh, subset)
#    5188     if dim in array.dims:
#    5189         dims = [d for d in array.dims if d != dim]
# -> 5190         count += np.asarray(array.count(dims))  # type: ignore[attr-defined]
#    5191         size += math.prod([self.dims[d] for d in dims])
#    5193 if thresh is not None:
#
# File ~/miniconda3/envs/XROMS/lib/python3.8/site-packages/xarray/core/common.py:156, in AbstractArray.__array__(self, dtype)
#     155 def __array__(self: Any, dtype: DTypeLike = None) -> np.ndarray:
# --> 156     return np.asarray(self.values, dtype=dtype)
#
# File ~/miniconda3/envs/XROMS/lib/python3.8/site-packages/xarray/core/variable.py:527, in Variable.values(self)
#     524 @property
#     525 def values(self):
#     526     """The variable's data as a numpy.ndarray"""
# --> 527     return _as_array_or_item(self._data)
#
# File ~/miniconda3/envs/XROMS/lib/python3.8/site-packages/xarray/core/variable.py:267, in _as_array_or_item(data)
#     253 def _as_array_or_item(data):
#     254     """Return the given values as a numpy array, or as an individual item if
#     255     it's a 0d datetime64 or timedelta64 array.
#     256
#    (...)
#     265     TODO: remove this (replace with np.asarray) once these issues are fixed
#     266     """
# --> 267     data = np.asarray(data)
#     268     if data.ndim == 0:
#     269         if data.dtype.kind == "M":
#
# File ~/miniconda3/envs/XROMS/lib/python3.8/site-packages/dask/array/core.py:1696, in Array.__array__(self, dtype, **kwargs)
#    1695 def __array__(self, dtype=None, **kwargs):
# -> 1696     x = self.compute()
#    1697     if dtype and x.dtype != dtype:
#    1698         x = x.astype(dtype)
#
# File ~/miniconda3/envs/XROMS/lib/python3.8/site-packages/dask/base.py:315, in DaskMethodsMixin.compute(self, **kwargs)
#     291 def compute(self, **kwargs):
#     292     """Compute this dask collection
#     293
#     294     This turns a lazy Dask collection into its in-memory equivalent.
#    (...)
#     313     dask.base.compute
#     314     """
# --> 315     (result,) = compute(self, traverse=False, **kwargs)
#     316     return result
#
# File ~/miniconda3/envs/XROMS/lib/python3.8/site-packages/dask/base.py:600, in compute(traverse, optimize_graph, scheduler, get, *args, **kwargs)
#     597     keys.append(x.__dask_keys__())
#     598     postcomputes.append(x.__dask_postcompute__())
# --> 600 results = schedule(dsk, keys, **kwargs)
#     601 return repack([f(r, *a) for r, (f, a) in zip(results, postcomputes)])
#
# File ~/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/client.py:3052, in Client.get(self, dsk, keys, workers, allow_other_workers, resources, sync, asynchronous, direct, retries, priority, fifo_timeout, actors, **kwargs)
#    3050         should_rejoin = False
#    3051 try:
# -> 3052     results = self.gather(packed, asynchronous=asynchronous, direct=direct)
#    3053 finally:
#    3054     for f in futures.values():
#
# File ~/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/client.py:2226, in Client.gather(self, futures, errors, direct, asynchronous)
#    2224 else:
#    2225     local_worker = None
# -> 2226 return self.sync(
#    2227     self._gather,
#    2228     futures,
#    2229     errors=errors,
#    2230     direct=direct,
#    2231     local_worker=local_worker,
#    2232     asynchronous=asynchronous,
#    2233 )
#
# File ~/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/utils.py:338, in SyncMethodMixin.sync(self, func, asynchronous, callback_timeout, *args, **kwargs)
#     336     return future
#     337 else:
# --> 338     return sync(
#     339         self.loop, func, *args, callback_timeout=callback_timeout, **kwargs
#     340     )
#
# File ~/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/utils.py:401, in sync(loop, func, callback_timeout, *args, **kwargs)
#     399 else:
#     400     while not e.is_set():
# --> 401         wait(10)
#     403 if error:
#     404     typ, exc, tb = error
#
# File ~/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/utils.py:390, in sync.<locals>.wait(timeout)
#     388 def wait(timeout):
#     389     try:
# --> 390         return e.wait(timeout)
#     391     except KeyboardInterrupt:
#     392         loop.add_callback(cancel)
#
# File ~/miniconda3/envs/XROMS/lib/python3.8/threading.py:558, in Event.wait(self, timeout)
#     556 signaled = self._flag
#     557 if not signaled:
# --> 558     signaled = self._cond.wait(timeout)
#     559 return signaled
#
# File ~/miniconda3/envs/XROMS/lib/python3.8/threading.py:306, in Condition.wait(self, timeout)
#     304 else:
#     305     if timeout > 0:
# --> 306         gotit = waiter.acquire(True, timeout)
#     307     else:
#     308         gotit = waiter.acquire(False)
#
# KeyboardInterrupt:
# tils_comm.py", line 368, in retry
#     return await coro()
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/core.py", line 1154, in send_recv_from_rpc
#     return await send_recv(comm=comm, op=key, **kwargs)
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/core.py", line 919, in send_recv
#     response = await comm.read(deserializers=deserializers)
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/comm/tcp.py", line 241, in read
#     convert_stream_closed_error(self, e)
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/comm/tcp.py", line 144, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) ConnectionPool.heartbeat_worker local=tcp://127.0.0.1:43628 remote=tcp://127.0.0.1:41596>: Stream is closed
# 2023-05-05 16:19:32,012 - distributed.worker - WARNING - Heartbeat to scheduler failed
# Traceback (most recent call last):
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nbytes = await stream.read_bytes(fmt_size)
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/worker.py", line 1178, in heartbeat
#     response = await retry_operation(
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/utils_comm.py", line 383, in retry_operation
#     return await retry(
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/utils_comm.py", line 368, in retry
#     return await coro()
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/core.py", line 1154, in send_recv_from_rpc
#     return await send_recv(comm=comm, op=key, **kwargs)
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/core.py", line 919, in send_recv
#     response = await comm.read(deserializers=deserializers)
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/comm/tcp.py", line 241, in read
#     convert_stream_closed_error(self, e)
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/comm/tcp.py", line 144, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) ConnectionPool.heartbeat_worker local=tcp://127.0.0.1:43614 remote=tcp://127.0.0.1:41596>: Stream is closed
# 2023-05-05 16:19:32,014 - distributed.nanny - ERROR - Worker process died unexpectedly
# 2023-05-05 16:19:32,014 - distributed.nanny - ERROR - Worker process died unexpectedly
# 2023-05-05 16:19:32,015 - distributed.nanny - ERROR - Worker process died unexpectedly
# 2023-05-05 16:19:32,016 - distributed.nanny - ERROR - Worker process died unexpectedly
# 2023-05-05 16:19:32,016 - distributed.nanny - ERROR - Worker process died unexpectedly
# 2023-05-05 16:19:32,016 - distributed.nanny - ERROR - Worker process died unexpectedly
# 2023-05-05 16:19:32,010 - distributed.worker - WARNING - Heartbeat to scheduler failed
# Traceback (most recent call last):
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nbytes = await stream.read_bytes(fmt_size)
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/worker.py", line 1178, in heartbeat
#     response = await retry_operation(
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/utils_comm.py", line 383, in retry_operation
#     return await retry(
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/utils_comm.py", line 368, in retry
#     return await coro()
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/core.py", line 1154, in send_recv_from_rpc
#     return await send_recv(comm=comm, op=key, **kwargs)
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/core.py", line 919, in send_recv
#     response = await comm.read(deserializers=deserializers)
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/comm/tcp.py", line 241, in read
#     convert_stream_closed_error(self, e)
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/comm/tcp.py", line 144, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) ConnectionPool.heartbeat_worker local=tcp://127.0.0.1:43616 remote=tcp://127.0.0.1:41596>: Stream is closed
# 2023-05-05 16:19:32,018 - distributed.nanny - ERROR - Worker process died unexpectedly
# 2023-05-05 16:19:32,018 - distributed.nanny - ERROR - Worker process died unexpectedly
# 2023-05-05 16:19:32,018 - distributed.nanny - ERROR - Worker process died unexpectedly
# 2023-05-05 16:19:32,012 - distributed.worker - WARNING - Heartbeat to scheduler failed
# Traceback (most recent call last):
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nbytes = await stream.read_bytes(fmt_size)
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/worker.py", line 1178, in heartbeat
#     response = await retry_operation(
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/utils_comm.py", line 383, in retry_operation
#     return await retry(
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/utils_comm.py", line 368, in retry
#     return await coro()
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/core.py", line 1154, in send_recv_from_rpc
#     return await send_recv(comm=comm, op=key, **kwargs)
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/core.py", line 919, in send_recv
#     response = await comm.read(deserializers=deserializers)
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/comm/tcp.py", line 241, in read
#     convert_stream_closed_error(self, e)
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/comm/tcp.py", line 144, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) ConnectionPool.heartbeat_worker local=tcp://127.0.0.1:43626 remote=tcp://127.0.0.1:41596>: Stream is closed
# 2023-05-05 16:19:32,023 - distributed.nanny - ERROR - Worker process died unexpectedly
# 2023-05-05 16:19:32,012 - distributed.worker - WARNING - Heartbeat to scheduler failed
# Traceback (most recent call last):
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nbytes = await stream.read_bytes(fmt_size)
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/worker.py", line 1178, in heartbeat
#     response = await retry_operation(
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/utils_comm.py", line 383, in retry_operation
#     return await retry(
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/utils_comm.py", line 368, in retry
#     return await coro()
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/core.py", line 1154, in send_recv_from_rpc
#     return await send_recv(comm=comm, op=key, **kwargs)
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/core.py", line 919, in send_recv
#     response = await comm.read(deserializers=deserializers)
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/comm/tcp.py", line 241, in read
#     convert_stream_closed_error(self, e)
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/comm/tcp.py", line 144, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) ConnectionPool.heartbeat_worker local=tcp://127.0.0.1:43606 remote=tcp://127.0.0.1:41596>: Stream is closed
# 2023-05-05 16:19:32,030 - distributed.nanny - ERROR - Worker process died unexpectedly
# 2023-05-05 16:19:32,087 - distributed.nanny - ERROR - Worker process died unexpectedly
# 2023-05-05 16:19:32,133 - distributed.nanny - ERROR - Worker process died unexpectedly

# %%
Eke_full=0.5*(Vf**2+Uf**2)

# %%
Eke_full.to_netcdf('/homes/metogra/iufarias/Documents/data/spec/100_int/KE/Eke_full.nc')
# Out:
# 2023-05-05 16:19:32,159 - distributed.nanny - ERROR - Worker process died unexpectedly
# Task exception was never retrieved
# future: <Task finished name='Task-325866' coro=<Client._gather.<locals>.wait() done, defined at /homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/client.py:2054> exception=AllExit()>
# Traceback (most recent call last):
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/client.py", line 2063, in wait
#     raise AllExit()
# distributed.client.AllExit
# 2023-05-05 16:19:33,899 - distributed.nanny - ERROR - Worker process died unexpectedly
# 2023-05-05 16:19:37,010 - distributed.nanny - ERROR - Worker process died unexpectedly
# 2023-05-05 16:19:37,010 - distributed.nanny - ERROR - Worker process died unexpectedly
# 2023-05-05 16:19:37,011 - distributed.nanny - ERROR - Worker process died unexpectedly
# 2023-05-05 16:19:37,012 - distributed.nanny - ERROR - Worker process died unexpectedly
# 2023-05-05 16:19:37,012 - distributed.nanny - ERROR - Worker process died unexpectedly
# 2023-05-05 16:19:37,013 - distributed.nanny - ERROR - Worker process died unexpectedly
# 2023-05-05 16:19:37,013 - distributed.nanny - ERROR - Worker process died unexpectedly
# 2023-05-05 16:19:40,114 - distributed.nanny - WARNING - Restarting worker
# 2023-05-05 16:19:40,288 - distributed.nanny - WARNING - Restarting worker
# 2023-05-05 16:19:40,290 - distributed.nanny - WARNING - Restarting worker
# 2023-05-05 16:19:40,291 - distributed.nanny - WARNING - Restarting worker
# 2023-05-05 16:19:40,293 - distributed.nanny - WARNING - Restarting worker
# 2023-05-05 16:19:40,294 - distributed.nanny - WARNING - Restarting worker
# 2023-05-05 16:19:40,296 - distributed.nanny - WARNING - Restarting worker
# 2023-05-05 16:19:40,302 - distributed.nanny - WARNING - Restarting worker
# 2023-05-05 16:19:40,304 - distributed.nanny - WARNING - Restarting worker
# 2023-05-05 16:19:40,459 - distributed.nanny - WARNING - Restarting worker
# 2023-05-05 16:19:40,496 - distributed.nanny - WARNING - Restarting worker
# 2023-05-05 16:19:40,560 - distributed.nanny - WARNING - Restarting worker
# 2023-05-05 16:19:40,564 - distributed.nanny - WARNING - Restarting worker
# 2023-05-05 16:19:40,567 - distributed.nanny - WARNING - Restarting worker
# 2023-05-05 16:19:40,569 - distributed.nanny - WARNING - Restarting worker
# 2023-05-05 16:19:40,572 - distributed.nanny - WARNING - Restarting worker
# 2023-05-05 16:19:40,575 - distributed.nanny - WARNING - Restarting worker
# 2023-05-05 16:19:40,578 - distributed.nanny - WARNING - Restarting worker
# 2023-05-05 16:19:40,672 - distributed.nanny - WARNING - Restarting worker
# 2023-05-05 16:19:40,741 - distributed.nanny - WARNING - Restarting worker
# 2023-05-05 16:19:40,746 - distributed.nanny - WARNING - Restarting worker
# 2023-05-05 16:19:40,841 - distributed.nanny - WARNING - Restarting worker
# 2023-05-05 16:19:40,874 - distributed.nanny - WARNING - Restarting worker
# 2023-05-05 16:19:40,952 - distributed.nanny - WARNING - Restarting worker
# 2023-05-05 16:19:40,986 - distributed.nanny - WARNING - Restarting worker
# 2023-05-05 16:19:40,990 - distributed.nanny - WARNING - Restarting worker
# 2023-05-05 16:19:41,023 - distributed.nanny - WARNING - Restarting worker
# 2023-05-05 16:19:41,060 - distributed.nanny - WARNING - Restarting worker
# 2023-05-05 16:19:41,066 - distributed.nanny - WARNING - Restarting worker
# 2023-05-05 16:19:41,126 - distributed.nanny - WARNING - Restarting worker
# 2023-05-05 16:19:41,132 - distributed.nanny - WARNING - Restarting worker
# 2023-05-05 16:19:41,164 - distributed.nanny - WARNING - Restarting worker
# 2023-05-05 16:19:41,168 - distributed.nanny - WARNING - Restarting worker
# 2023-05-05 16:19:41,172 - distributed.nanny - WARNING - Restarting worker
# 2023-05-05 16:19:41,175 - distributed.nanny - WARNING - Restarting worker
# 2023-05-05 16:19:41,219 - distributed.nanny - WARNING - Restarting worker
# 2023-05-05 16:19:41,636 - distributed.nanny - WARNING - Restarting worker
# 2023-05-05 16:19:41,638 - distributed.nanny - WARNING - Restarting worker
# 2023-05-05 16:19:41,640 - distributed.nanny - WARNING - Restarting worker
# 2023-05-05 16:19:41,756 - distributed.nanny - WARNING - Restarting worker
# 2023-05-05 16:19:41,799 - distributed.nanny - WARNING - Restarting worker
# 2023-05-05 16:19:41,803 - distributed.nanny - WARNING - Restarting worker
# 2023-05-05 16:19:41,808 - distributed.nanny - WARNING - Restarting worker
# 2023-05-05 16:19:41,810 - distributed.nanny - WARNING - Restarting worker
# 2023-05-05 16:19:41,812 - distributed.nanny - WARNING - Restarting worker
# 2023-05-05 16:19:41,988 - distributed.nanny - WARNING - Restarting worker
# 2023-05-05 16:19:41,992 - distributed.nanny - WARNING - Restarting worker
# 2023-05-05 16:19:42,167 - distributed.nanny - WARNING - Restarting worker
# 2023-05-05 16:19:42,169 - distributed.nanny - WARNING - Restarting worker
# 2023-05-05 16:19:42,174 - distributed.nanny - WARNING - Restarting worker
# 2023-05-05 16:19:42,175 - distributed.nanny - WARNING - Restarting worker
# 2023-05-05 16:19:42,322 - distributed.nanny - WARNING - Restarting worker
# 2023-05-05 16:19:42,376 - distributed.nanny - WARNING - Restarting worker
# 2023-05-05 16:19:42,379 - distributed.nanny - WARNING - Restarting worker
# 2023-05-05 16:19:42,380 - distributed.nanny - WARNING - Restarting worker
# Fatal Python error: Fatal Python error: init_import_sizeinit_import_sizeFatal Python error: : : Fatal Python error: Failed to import the site moduleinit_import_sizeFailed to import the site moduleinit_import_size
#
# : Python runtime state: : Python runtime state: initializedFailed to import the site moduleinitialized
# Failed to import the site module
#
#
# Python runtime state: initializedPython runtime state:
# initialized
# Fatal Python error: init_import_size: Failed to import the site module
# Python runtime state: initialized
# Fatal Python error: init_import_size: Failed to import the site module
# Python runtime state: initialized
# Fatal Python error: init_import_size: Failed to import the site module
# Python runtime state: initialized
# Fatal Python error: init_import_size: Failed to import the site module
# Python runtime state: initialized
# Fatal Python error: init_import_size: Fatal Python error: Failed to import the site moduleinit_import_size
# : Python runtime state: initialized
# Failed to import the site module
# Python runtime state: initialized
# Fatal Python error: init_import_size: Failed to import the site module
# Python runtime state: initialized
# Fatal Python error: init_import_size: Failed to import the site module
# Python runtime state: initialized
# Fatal Python error: init_import_size: Failed to import the site module
# Python runtime state: initialized
# Fatal Python error: init_import_size: Failed to import the site module
# Python runtime state: initialized
# Fatal Python error: init_import_size: Failed to import the site module
# Python runtime state: initialized
# Fatal Python error: init_import_size: Failed to import the site module
# Python runtime state: initialized
# Fatal Python error: init_import_size: Failed to import the site module
# Python runtime state: initialized
# Fatal Python error: init_import_size: Failed to import the site module
# Python runtime state: initialized
# Fatal Python error: init_import_size: Failed to import the site module
# Python runtime state: initialized
# Fatal Python error: init_import_size: Failed to import the site module
# Python runtime state: initialized
# Traceback (most recent call last):
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site.py", line 580, in <module>
#     main()
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site.py", line 567, in main
#     known_paths = addsitepackages(known_paths)
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site.py", line 350, in addsitepackages
#     addsitedir(sitedir, known_paths)
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site.py", line 208, in addsitedir
#     addpackage(sitedir, name, known_paths)
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site.py", line 160, in addpackage
#     f = io.TextIOWrapper(io.open_code(fullname))
# KeyboardInterrupt
# Traceback (most recent call last):
#   File "<string>", line 1, in <module>
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/multiprocessing/spawn.py", line 112, in spawn_main
#     from . import resource_tracker
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/multiprocessing/resource_tracker.py", line 37, in <module>
#     import _multiprocessing
# KeyboardInterrupt
# Traceback (most recent call last):
#   File "<string>", line 1, in <module>
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/multiprocessing/spawn.py", line 112, in spawn_main
#     from . import resource_tracker
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/multiprocessing/resource_tracker.py", line 38, in <module>
#     import _posixshmem
# KeyboardInterrupt
# Task exception was never retrieved
# future: <Task finished name='Task-326554' coro=<Client._gather.<locals>.wait() done, defined at /homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/client.py:2054> exception=AllExit()>
# Traceback (most recent call last):
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/client.py", line 2063, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-326582' coro=<Client._gather.<locals>.wait() done, defined at /homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/client.py:2054> exception=AllExit()>
# Traceback (most recent call last):
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/client.py", line 2063, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-326576' coro=<Client._gather.<locals>.wait() done, defined at /homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/client.py:2054> exception=AllExit()>
# Traceback (most recent call last):
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/client.py", line 2063, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-326595' coro=<Client._gather.<locals>.wait() done, defined at /homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/client.py:2054> exception=AllExit()>
# Traceback (most recent call last):
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/client.py", line 2063, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-326538' coro=<Client._gather.<locals>.wait() done, defined at /homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/client.py:2054> exception=AllExit()>
# Traceback (most recent call last):
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/client.py", line 2063, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-326518' coro=<Client._gather.<locals>.wait() done, defined at /homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/client.py:2054> exception=AllExit()>
# Traceback (most recent call last):
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/client.py", line 2063, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-326491' coro=<Client._gather.<locals>.wait() done, defined at /homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/client.py:2054> exception=AllExit()>
# Traceback (most recent call last):
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/client.py", line 2063, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-326570' coro=<Client._gather.<locals>.wait() done, defined at /homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/client.py:2054> exception=AllExit()>
# Traceback (most recent call last):
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/client.py", line 2063, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-326541' coro=<Client._gather.<locals>.wait() done, defined at /homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/client.py:2054> exception=AllExit()>
# Traceback (most recent call last):
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/client.py", line 2063, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-326485' coro=<Client._gather.<locals>.wait() done, defined at /homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/client.py:2054> exception=AllExit()>
# Traceback (most recent call last):
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/client.py", line 2063, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-326573' coro=<Client._gather.<locals>.wait() done, defined at /homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/client.py:2054> exception=AllExit()>
# Traceback (most recent call last):
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/client.py", line 2063, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-326597' coro=<Client._gather.<locals>.wait() done, defined at /homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/client.py:2054> exception=AllExit()>
# Traceback (most recent call last):
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/client.py", line 2063, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-326527' coro=<Client._gather.<locals>.wait() done, defined at /homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/client.py:2054> exception=AllExit()>
# Traceback (most recent call last):
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/client.py", line 2063, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-326535' coro=<Client._gather.<locals>.wait() done, defined at /homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/client.py:2054> exception=AllExit()>
# Traceback (most recent call last):
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/client.py", line 2063, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-326545' coro=<Client._gather.<locals>.wait() done, defined at /homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/client.py:2054> exception=AllExit()>
# Traceback (most recent call last):
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/client.py", line 2063, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-326519' coro=<Client._gather.<locals>.wait() done, defined at /homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/client.py:2054> exception=AllExit()>
# Traceback (most recent call last):
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/client.py", line 2063, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-326530' coro=<Client._gather.<locals>.wait() done, defined at /homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/client.py:2054> exception=AllExit()>
# Traceback (most recent call last):
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/client.py", line 2063, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-326557' coro=<Client._gather.<locals>.wait() done, defined at /homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/client.py:2054> exception=AllExit()>
# Traceback (most recent call last):
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/client.py", line 2063, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-326523' coro=<Client._gather.<locals>.wait() done, defined at /homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/client.py:2054> exception=AllExit()>
# Traceback (most recent call last):
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/client.py", line 2063, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-326542' coro=<Client._gather.<locals>.wait() done, defined at /homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/client.py:2054> exception=AllExit()>
# Traceback (most recent call last):
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/client.py", line 2063, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-326547' coro=<Client._gather.<locals>.wait() done, defined at /homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/client.py:2054> exception=AllExit()>
# Traceback (most recent call last):
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/client.py", line 2063, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-326549' coro=<Client._gather.<locals>.wait() done, defined at /homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/client.py:2054> exception=AllExit()>
# Traceback (most recent call last):
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/client.py", line 2063, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-326550' coro=<Client._gather.<locals>.wait() done, defined at /homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/client.py:2054> exception=AllExit()>
# Traceback (most recent call last):
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/client.py", line 2063, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-326517' coro=<Client._gather.<locals>.wait() done, defined at /homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/client.py:2054> exception=AllExit()>
# Traceback (most recent call last):
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/client.py", line 2063, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-326546' coro=<Client._gather.<locals>.wait() done, defined at /homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/client.py:2054> exception=AllExit()>
# Traceback (most recent call last):
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/client.py", line 2063, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-326555' coro=<Client._gather.<locals>.wait() done, defined at /homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/client.py:2054> exception=AllExit()>
# Traceback (most recent call last):
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/client.py", line 2063, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-326540' coro=<Client._gather.<locals>.wait() done, defined at /homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/client.py:2054> exception=AllExit()>
# Traceback (most recent call last):
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/client.py", line 2063, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-326544' coro=<Client._gather.<locals>.wait() done, defined at /homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/client.py:2054> exception=AllExit()>
# Traceback (most recent call last):
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/client.py", line 2063, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-326522' coro=<Client._gather.<locals>.wait() done, defined at /homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/client.py:2054> exception=AllExit()>
# Traceback (most recent call last):
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/client.py", line 2063, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-326536' coro=<Client._gather.<locals>.wait() done, defined at /homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/client.py:2054> exception=AllExit()>
# Traceback (most recent call last):
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/client.py", line 2063, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-326525' coro=<Client._gather.<locals>.wait() done, defined at /homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/client.py:2054> exception=AllExit()>
# Traceback (most recent call last):
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/client.py", line 2063, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-326580' coro=<Client._gather.<locals>.wait() done, defined at /homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/client.py:2054> exception=AllExit()>
# Traceback (most recent call last):
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/client.py", line 2063, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-326511' coro=<Client._gather.<locals>.wait() done, defined at /homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/client.py:2054> exception=AllExit()>
# Traceback (most recent call last):
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/client.py", line 2063, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-326556' coro=<Client._gather.<locals>.wait() done, defined at /homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/client.py:2054> exception=AllExit()>
# Traceback (most recent call last):
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/client.py", line 2063, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-326561' coro=<Client._gather.<locals>.wait() done, defined at /homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/client.py:2054> exception=AllExit()>
# Traceback (most recent call last):
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/client.py", line 2063, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-326587' coro=<Client._gather.<locals>.wait() done, defined at /homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/client.py:2054> exception=AllExit()>
# Traceback (most recent call last):
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/client.py", line 2063, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-326577' coro=<Client._gather.<locals>.wait() done, defined at /homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/client.py:2054> exception=AllExit()>
# Traceback (most recent call last):
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/client.py", line 2063, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-326601' coro=<Client._gather.<locals>.wait() done, defined at /homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/client.py:2054> exception=AllExit()>
# Traceback (most recent call last):
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/client.py", line 2063, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-326590' coro=<Client._gather.<locals>.wait() done, defined at /homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/client.py:2054> exception=AllExit()>
# Traceback (most recent call last):
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/client.py", line 2063, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-326598' coro=<Client._gather.<locals>.wait() done, defined at /homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/client.py:2054> exception=AllExit()>
# Traceback (most recent call last):
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/client.py", line 2063, in wait
#     raise AllExit()
# distributed.client.AllExit
# Traceback (most recent call last):
#   File "<string>", line 1, in <module>
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/multiprocessing/__init__.py", line 16, in <module>
#     from . import context
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/multiprocessing/context.py", line 6, in <module>
#     from . import reduction
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/multiprocessing/reduction.py", line 140, in <module>
#     import array
# KeyboardInterrupt
# Task exception was never retrieved
# future: <Task finished name='Task-326589' coro=<Client._gather.<locals>.wait() done, defined at /homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/client.py:2054> exception=AllExit()>
# Traceback (most recent call last):
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/client.py", line 2063, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-326581' coro=<Client._gather.<locals>.wait() done, defined at /homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/client.py:2054> exception=AllExit()>
# Traceback (most recent call last):
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/client.py", line 2063, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-326575' coro=<Client._gather.<locals>.wait() done, defined at /homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/client.py:2054> exception=AllExit()>
# Traceback (most recent call last):
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/client.py", line 2063, in wait
#     raise AllExit()
# distributed.client.AllExit
# Traceback (most recent call last):
#   File "<string>", line 1, in <module>
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/multiprocessing/__init__.py", line 16, in <module>
#     from . import context
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/multiprocessing/context.py", line 6, in <module>
#     from . import reduction
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/multiprocessing/reduction.py", line 15, in <module>
#     import pickle
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/pickle.py", line 33, in <module>
#     from struct import pack, unpack
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/struct.py", line 13, in <module>
#     from _struct import *
# KeyboardInterrupt
# Task exception was never retrieved
# future: <Task finished name='Task-326501' coro=<Client._gather.<locals>.wait() done, defined at /homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/client.py:2054> exception=AllExit()>
# Traceback (most recent call last):
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/client.py", line 2063, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-326551' coro=<Client._gather.<locals>.wait() done, defined at /homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/client.py:2054> exception=AllExit()>
# Traceback (most recent call last):
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/client.py", line 2063, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-326532' coro=<Client._gather.<locals>.wait() done, defined at /homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/client.py:2054> exception=AllExit()>
# Traceback (most recent call last):
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/client.py", line 2063, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-326521' coro=<Client._gather.<locals>.wait() done, defined at /homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/client.py:2054> exception=AllExit()>
# Traceback (most recent call last):
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/client.py", line 2063, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-326524' coro=<Client._gather.<locals>.wait() done, defined at /homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/client.py:2054> exception=AllExit()>
# Traceback (most recent call last):
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/client.py", line 2063, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-326553' coro=<Client._gather.<locals>.wait() done, defined at /homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/client.py:2054> exception=AllExit()>
# Traceback (most recent call last):
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/client.py", line 2063, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-326552' coro=<Client._gather.<locals>.wait() done, defined at /homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/client.py:2054> exception=AllExit()>
# Traceback (most recent call last):
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/client.py", line 2063, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-326548' coro=<Client._gather.<locals>.wait() done, defined at /homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/client.py:2054> exception=AllExit()>
# Traceback (most recent call last):
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/client.py", line 2063, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-326528' coro=<Client._gather.<locals>.wait() done, defined at /homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/client.py:2054> exception=AllExit()>
# Traceback (most recent call last):
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/client.py", line 2063, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-326496' coro=<Client._gather.<locals>.wait() done, defined at /homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/client.py:2054> exception=AllExit()>
# Traceback (most recent call last):
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/client.py", line 2063, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-326493' coro=<Client._gather.<locals>.wait() done, defined at /homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/client.py:2054> exception=AllExit()>
# Traceback (most recent call last):
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/client.py", line 2063, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-326490' coro=<Client._gather.<locals>.wait() done, defined at /homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/client.py:2054> exception=AllExit()>
# Traceback (most recent call last):
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/client.py", line 2063, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-326560' coro=<Client._gather.<locals>.wait() done, defined at /homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/client.py:2054> exception=AllExit()>
# Traceback (most recent call last):
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/client.py", line 2063, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-326506' coro=<Client._gather.<locals>.wait() done, defined at /homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/client.py:2054> exception=AllExit()>
# Traceback (most recent call last):
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/client.py", line 2063, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-326539' coro=<Client._gather.<locals>.wait() done, defined at /homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/client.py:2054> exception=AllExit()>
# Traceback (most recent call last):
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/client.py", line 2063, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-326498' coro=<Client._gather.<locals>.wait() done, defined at /homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/client.py:2054> exception=AllExit()>
# Traceback (most recent call last):
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/client.py", line 2063, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-326508' coro=<Client._gather.<locals>.wait() done, defined at /homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/client.py:2054> exception=AllExit()>
# Traceback (most recent call last):
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/client.py", line 2063, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-326520' coro=<Client._gather.<locals>.wait() done, defined at /homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/client.py:2054> exception=AllExit()>
# Traceback (most recent call last):
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/client.py", line 2063, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-326512' coro=<Client._gather.<locals>.wait() done, defined at /homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/client.py:2054> exception=AllExit()>
# Traceback (most recent call last):
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/client.py", line 2063, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-326486' coro=<Client._gather.<locals>.wait() done, defined at /homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/client.py:2054> exception=AllExit()>
# Traceback (most recent call last):
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/client.py", line 2063, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-326531' coro=<Client._gather.<locals>.wait() done, defined at /homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/client.py:2054> exception=AllExit()>
# Traceback (most recent call last):
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/client.py", line 2063, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-326499' coro=<Client._gather.<locals>.wait() done, defined at /homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/client.py:2054> exception=AllExit()>
# Traceback (most recent call last):
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/client.py", line 2063, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-326515' coro=<Client._gather.<locals>.wait() done, defined at /homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/client.py:2054> exception=AllExit()>
# Traceback (most recent call last):
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/client.py", line 2063, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-326489' coro=<Client._gather.<locals>.wait() done, defined at /homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/client.py:2054> exception=AllExit()>
# Traceback (most recent call last):
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/client.py", line 2063, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-326492' coro=<Client._gather.<locals>.wait() done, defined at /homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/client.py:2054> exception=AllExit()>
# Traceback (most recent call last):
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/client.py", line 2063, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-326572' coro=<Client._gather.<locals>.wait() done, defined at /homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/client.py:2054> exception=AllExit()>
# Traceback (most recent call last):
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/client.py", line 2063, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-326504' coro=<Client._gather.<locals>.wait() done, defined at /homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/client.py:2054> exception=AllExit()>
# Traceback (most recent call last):
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/client.py", line 2063, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-326537' coro=<Client._gather.<locals>.wait() done, defined at /homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/client.py:2054> exception=AllExit()>
# Traceback (most recent call last):
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/client.py", line 2063, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-326505' coro=<Client._gather.<locals>.wait() done, defined at /homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/client.py:2054> exception=AllExit()>
# Traceback (most recent call last):
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/client.py", line 2063, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-326497' coro=<Client._gather.<locals>.wait() done, defined at /homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/client.py:2054> exception=AllExit()>
# Traceback (most recent call last):
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/client.py", line 2063, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-326495' coro=<Client._gather.<locals>.wait() done, defined at /homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/client.py:2054> exception=AllExit()>
# Traceback (most recent call last):
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/client.py", line 2063, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-326500' coro=<Client._gather.<locals>.wait() done, defined at /homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/client.py:2054> exception=AllExit()>
# Traceback (most recent call last):
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/client.py", line 2063, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-326484' coro=<Client._gather.<locals>.wait() done, defined at /homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/client.py:2054> exception=AllExit()>
# Traceback (most recent call last):
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/client.py", line 2063, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-326514' coro=<Client._gather.<locals>.wait() done, defined at /homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/client.py:2054> exception=AllExit()>
# Traceback (most recent call last):
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/client.py", line 2063, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-326502' coro=<Client._gather.<locals>.wait() done, defined at /homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/client.py:2054> exception=AllExit()>
# Traceback (most recent call last):
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/client.py", line 2063, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-326510' coro=<Client._gather.<locals>.wait() done, defined at /homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/client.py:2054> exception=AllExit()>
# Traceback (most recent call last):
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/client.py", line 2063, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-326516' coro=<Client._gather.<locals>.wait() done, defined at /homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/client.py:2054> exception=AllExit()>
# Traceback (most recent call last):
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/client.py", line 2063, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-326529' coro=<Client._gather.<locals>.wait() done, defined at /homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/client.py:2054> exception=AllExit()>
# Traceback (most recent call last):
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/client.py", line 2063, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-326526' coro=<Client._gather.<locals>.wait() done, defined at /homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/client.py:2054> exception=AllExit()>
# Traceback (most recent call last):
# ...
#     import threading
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/threading.py", line 8, in <module>
#     from _weakrefset import WeakSet
#   File "<frozen importlib._bootstrap>", line 991, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 975, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 671, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 839, in exec_module
#   File "<frozen importlib._bootstrap_external>", line 934, in get_code
#   File "<frozen importlib._bootstrap_external>", line 1033, in get_data
# KeyboardInterrupt
# Traceback (most recent call last):
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site.py", line 580, in <module>
#     main()
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site.py", line 567, in main
#     known_paths = addsitepackages(known_paths)
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site.py", line 350, in addsitepackages
#     addsitedir(sitedir, known_paths)
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site.py", line 208, in addsitedir
#     addpackage(sitedir, name, known_paths)
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site.py", line 169, in addpackage
#     exec(line)
#   File "<string>", line 1, in <module>
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/__editable___xroms_0_1_dev155_g7d4777c_finder.py", line 6, in <module>
#     from pathlib import Path
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/pathlib.py", line 1, in <module>
#     import fnmatch
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/fnmatch.py", line 14, in <module>
#     import re
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/re.py", line 125, in <module>
#     import sre_compile
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/sre_compile.py", line 14, in <module>
#     import sre_parse
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/sre_parse.py", line 15, in <module>
#     from sre_constants import *
#   File "<frozen importlib._bootstrap>", line 991, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 975, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 671, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 839, in exec_module
#   File "<frozen importlib._bootstrap_external>", line 934, in get_code
#   File "<frozen importlib._bootstrap_external>", line 1032, in get_data
# KeyboardInterrupt
# Traceback (most recent call last):
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site.py", line 580, in <module>
#     main()
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site.py", line 567, in main
#     known_paths = addsitepackages(known_paths)
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site.py", line 350, in addsitepackages
#     addsitedir(sitedir, known_paths)
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site.py", line 208, in addsitedir
#     addpackage(sitedir, name, known_paths)
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site.py", line 169, in addpackage
#     exec(line)
#   File "<string>", line 1, in <module>
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/__editable___xroms_0_1_dev155_g7d4777c_finder.py", line 6, in <module>
#     from pathlib import Path
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/pathlib.py", line 1, in <module>
#     import fnmatch
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/fnmatch.py", line 14, in <module>
#     import re
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/re.py", line 125, in <module>
#     import sre_compile
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/sre_compile.py", line 14, in <module>
#     import sre_parse
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/sre_parse.py", line 15, in <module>
#     from sre_constants import *
#   File "<frozen importlib._bootstrap>", line 991, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 975, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 671, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 839, in exec_module
#   File "<frozen importlib._bootstrap_external>", line 934, in get_code
#   File "<frozen importlib._bootstrap_external>", line 1032, in get_data
# KeyboardInterrupt
# Traceback (most recent call last):
#   File "<string>", line 1, in <module>
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/multiprocessing/__init__.py", line 16, in <module>
#     from . import context
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/multiprocessing/context.py", line 6, in <module>
#     from . import reduction
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/multiprocessing/reduction.py", line 15, in <module>
#     import pickle
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/pickle.py", line 37, in <module>
#     import _compat_pickle
#   File "<frozen importlib._bootstrap>", line 991, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 975, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 671, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 839, in exec_module
#   File "<frozen importlib._bootstrap_external>", line 934, in get_code
#   File "<frozen importlib._bootstrap_external>", line 1032, in get_data
# KeyboardInterrupt
# Traceback (most recent call last):
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site.py", line 580, in <module>
#     main()
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site.py", line 567, in main
#     known_paths = addsitepackages(known_paths)
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site.py", line 350, in addsitepackages
#     addsitedir(sitedir, known_paths)
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site.py", line 208, in addsitedir
#     addpackage(sitedir, name, known_paths)
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site.py", line 169, in addpackage
#     exec(line)
#   File "<string>", line 1, in <module>
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/__editable___xroms_0_1_dev155_g7d4777c_finder.py", line 6, in <module>
#     from pathlib import Path
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/pathlib.py", line 1, in <module>
#     import fnmatch
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/fnmatch.py", line 14, in <module>
#     import re
#   File "<frozen importlib._bootstrap>", line 991, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 975, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 671, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 839, in exec_module
#   File "<frozen importlib._bootstrap_external>", line 934, in get_code
#   File "<frozen importlib._bootstrap_external>", line 1032, in get_data
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [273], line 1
# ----> 1 Eke_full.to_netcdf('/homes/metogra/iufarias/Documents/data/spec/100_int/KE/Eke_full.nc')
#
# File ~/miniconda3/envs/XROMS/lib/python3.8/site-packages/xarray/core/dataarray.py:3217, in DataArray.to_netcdf(self, path, mode, format, group, engine, encoding, unlimited_dims, compute, invalid_netcdf)
#    3213 else:
#    3214     # No problems with the name - so we're fine!
#    3215     dataset = self.to_dataset()
# -> 3217 return to_netcdf(  # type: ignore  # mypy cannot resolve the overloads:(
#    3218     dataset,
#    3219     path,
#    3220     mode=mode,
#    3221     format=format,
#    3222     group=group,
#    3223     engine=engine,
#    3224     encoding=encoding,
#    3225     unlimited_dims=unlimited_dims,
#    3226     compute=compute,
#    3227     multifile=False,
#    3228     invalid_netcdf=invalid_netcdf,
#    3229 )
#
# File ~/miniconda3/envs/XROMS/lib/python3.8/site-packages/xarray/backends/api.py:1210, in to_netcdf(dataset, path_or_file, mode, format, group, engine, encoding, unlimited_dims, compute, multifile, invalid_netcdf)
#    1205 # TODO: figure out how to refactor this logic (here and in save_mfdataset)
#    1206 # to avoid this mess of conditionals
#    1207 try:
#    1208     # TODO: allow this work (setting up the file for writing array data)
#    1209     # to be parallelized with dask
# -> 1210     dump_to_store(
#    1211         dataset, store, writer, encoding=encoding, unlimited_dims=unlimited_dims
#    1212     )
#    1213     if autoclose:
#    1214         store.close()
#
# File ~/miniconda3/envs/XROMS/lib/python3.8/site-packages/xarray/backends/api.py:1257, in dump_to_store(dataset, store, writer, encoder, encoding, unlimited_dims)
#    1254 if encoder:
#    1255     variables, attrs = encoder(variables, attrs)
# -> 1257 store.store(variables, attrs, check_encoding, writer, unlimited_dims=unlimited_dims)
#
# File ~/miniconda3/envs/XROMS/lib/python3.8/site-packages/xarray/backends/common.py:263, in AbstractWritableDataStore.store(self, variables, attributes, check_encoding_set, writer, unlimited_dims)
#     260 if writer is None:
#     261     writer = ArrayWriter()
# --> 263 variables, attributes = self.encode(variables, attributes)
#     265 self.set_attributes(attributes)
#     266 self.set_dimensions(variables, unlimited_dims=unlimited_dims)
#
# File ~/miniconda3/envs/XROMS/lib/python3.8/site-packages/xarray/backends/common.py:352, in WritableCFDataStore.encode(self, variables, attributes)
#     349 def encode(self, variables, attributes):
#     350     # All NetCDF files get CF encoded by default, without this attempting
#     351     # to write times, for example, would fail.
# --> 352     variables, attributes = cf_encoder(variables, attributes)
#     353     variables = {k: self.encode_variable(v) for k, v in variables.items()}
#     354     attributes = {k: self.encode_attribute(v) for k, v in attributes.items()}
#
# File ~/miniconda3/envs/XROMS/lib/python3.8/site-packages/xarray/conventions.py:864, in cf_encoder(variables, attributes)
#     861 # add encoding for time bounds variables if present.
#     862 _update_bounds_encoding(variables)
# --> 864 new_vars = {k: encode_cf_variable(v, name=k) for k, v in variables.items()}
#     866 # Remove attrs from bounds variables (issue #2921)
#     867 for var in new_vars.values():
#
# File ~/miniconda3/envs/XROMS/lib/python3.8/site-packages/xarray/conventions.py:864, in <dictcomp>(.0)
#     861 # add encoding for time bounds variables if present.
#     862 _update_bounds_encoding(variables)
# --> 864 new_vars = {k: encode_cf_variable(v, name=k) for k, v in variables.items()}
#     866 # Remove attrs from bounds variables (issue #2921)
#     867 for var in new_vars.values():
#
# File ~/miniconda3/envs/XROMS/lib/python3.8/site-packages/xarray/conventions.py:273, in encode_cf_variable(var, needs_copy, name)
#     264 ensure_not_multiindex(var, name=name)
#     266 for coder in [
#     267     times.CFDatetimeCoder(),
#     268     times.CFTimedeltaCoder(),
#    (...)
#     271     variables.UnsignedIntegerCoder(),
#     272 ]:
# --> 273     var = coder.encode(var, name=name)
#     275 # TODO(shoyer): convert all of these to use coders, too:
#     276 var = maybe_encode_nonstring_dtype(var, name=name)
#
# File ~/miniconda3/envs/XROMS/lib/python3.8/site-packages/xarray/coding/times.py:668, in CFDatetimeCoder.encode(self, variable, name)
#     664 dims, data, attrs, encoding = unpack_for_encoding(variable)
#     665 if np.issubdtype(data.dtype, np.datetime64) or contains_cftime_datetimes(
#     666     variable
#     667 ):
# --> 668     (data, units, calendar) = encode_cf_datetime(
#     669         data, encoding.pop("units", None), encoding.pop("calendar", None)
#     670     )
#     671     safe_setitem(attrs, "units", units, name=name)
#     672     safe_setitem(attrs, "calendar", calendar, name=name)
#
# File ~/miniconda3/envs/XROMS/lib/python3.8/site-packages/xarray/coding/times.py:601, in encode_cf_datetime(dates, units, calendar)
#     591 def encode_cf_datetime(dates, units=None, calendar=None):
#     592     """Given an array of datetime objects, returns the tuple `(num, units,
#     593     calendar)` suitable for a CF compliant time variable.
#     594
#    (...)
#     599     cftime.date2num
#     600     """
# --> 601     dates = np.asarray(dates)
#     603     if units is None:
#     604         units = infer_datetime_units(dates)
#
# File ~/miniconda3/envs/XROMS/lib/python3.8/site-packages/dask/array/core.py:1696, in Array.__array__(self, dtype, **kwargs)
#    1695 def __array__(self, dtype=None, **kwargs):
# -> 1696     x = self.compute()
#    1697     if dtype and x.dtype != dtype:
#    1698         x = x.astype(dtype)
#
# File ~/miniconda3/envs/XROMS/lib/python3.8/site-packages/dask/base.py:315, in DaskMethodsMixin.compute(self, **kwargs)
#     291 def compute(self, **kwargs):
#     292     """Compute this dask collection
#     293
#     294     This turns a lazy Dask collection into its in-memory equivalent.
#    (...)
#     313     dask.base.compute
#     314     """
# --> 315     (result,) = compute(self, traverse=False, **kwargs)
#     316     return result
#
# File ~/miniconda3/envs/XROMS/lib/python3.8/site-packages/dask/base.py:600, in compute(traverse, optimize_graph, scheduler, get, *args, **kwargs)
#     597     keys.append(x.__dask_keys__())
#     598     postcomputes.append(x.__dask_postcompute__())
# --> 600 results = schedule(dsk, keys, **kwargs)
#     601 return repack([f(r, *a) for r, (f, a) in zip(results, postcomputes)])
#
# File ~/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/client.py:3052, in Client.get(self, dsk, keys, workers, allow_other_workers, resources, sync, asynchronous, direct, retries, priority, fifo_timeout, actors, **kwargs)
#    3050         should_rejoin = False
#    3051 try:
# -> 3052     results = self.gather(packed, asynchronous=asynchronous, direct=direct)
#    3053 finally:
#    3054     for f in futures.values():
#
# File ~/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/client.py:2226, in Client.gather(self, futures, errors, direct, asynchronous)
#    2224 else:
#    2225     local_worker = None
# -> 2226 return self.sync(
#    2227     self._gather,
#    2228     futures,
#    2229     errors=errors,
#    2230     direct=direct,
#    2231     local_worker=local_worker,
#    2232     asynchronous=asynchronous,
#    2233 )
#
# File ~/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/utils.py:338, in SyncMethodMixin.sync(self, func, asynchronous, callback_timeout, *args, **kwargs)
#     336     return future
#     337 else:
# --> 338     return sync(
#     339         self.loop, func, *args, callback_timeout=callback_timeout, **kwargs
#     340     )
#
# File ~/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/utils.py:401, in sync(loop, func, callback_timeout, *args, **kwargs)
#     399 else:
#     400     while not e.is_set():
# --> 401         wait(10)
#     403 if error:
#     404     typ, exc, tb = error
#
# File ~/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/utils.py:390, in sync.<locals>.wait(timeout)
#     388 def wait(timeout):
#     389     try:
# --> 390         return e.wait(timeout)
#     391     except KeyboardInterrupt:
#     392         loop.add_callback(cancel)
#
# File ~/miniconda3/envs/XROMS/lib/python3.8/threading.py:558, in Event.wait(self, timeout)
#     556 signaled = self._flag
#     557 if not signaled:
# --> 558     signaled = self._cond.wait(timeout)
#     559 return signaled
#
# File ~/miniconda3/envs/XROMS/lib/python3.8/threading.py:306, in Condition.wait(self, timeout)
#     304 else:
#     305     if timeout > 0:
# --> 306         gotit = waiter.acquire(True, timeout)
#     307     else:
#     308         gotit = waiter.acquire(False)
#
# KeyboardInterrupt:

# %% [markdown]
# #### EKE (SMTH)

# %%
v_smth_psi=dt.v.xroms.to_grid('psi', 's_rho')
v_smth_interp=v_smth_psi.xroms.isoslice(np.linspace(-5,-50, 10))[:,:,120:-120,120:800]

# %%
u_smth_psi=dt.u.xroms.to_grid('psi', 's_rho')
u_smth_interp=u_smth_psi.xroms.isoslice(np.linspace(-5,-50, 10))[:,:,120:-120,120:800]

# %%
# %%time

with ProgressBar():
    Ut=xrft.isotropic_power_spectrum(u_smth_interp,
                                      dim=['eta_v','xi_u'],
                              nfactor=nf,truncate='True',scaling=scl,detrend='linear', 
                                     window=wdws,window_correction=wdw_cor)

with ProgressBar():
    Vt=xrft.isotropic_power_spectrum(v_smth_interp,
                                      dim=['eta_v','xi_u'],
                              nfactor=nf,truncate='True',scaling=scl,detrend='linear', 
                                     window=wdws,window_correction=wdw_cor)
# Out:
# CPU times: user 3min 42s, sys: 1min 40s, total: 5min 23s
# Wall time: 17min 50s

# %%
Eke_smth=0.5*(Ut**2+Vt**2)

# %%
Eke_smth.to_netcdf('/homes/metogra/iufarias/Documents/data/spec/100_int/KE/Eke_smth.nc')

# %% [markdown]
# #### EPE (FULL)

# %%
rho_full_psi=df.rho.xroms.to_grid('psi', 's_rho')
rho_full_interp=rho_full_psi.xroms.isoslice(np.linspace(-5,-50, 10))[:,:,120:-120,120:800]
# Out:
# CPU times: user 174 ms, sys: 3.62 ms, total: 178 ms
# Wall time: 174 ms

# %%
b_full_interp=xroms.buoyancy(rho_full_interp)
# rho_full_interp=xroms.potential_density(t_full_interp,s_full_interp)
# bf=xroms.buoyancy(rho_full_interp-1025)

# %%
# %%time
with ProgressBar():
    Bf=xrft.isotropic_power_spectrum(b_full_interp,
                                      dim=['eta_v','xi_u'],
                              nfactor=nf,truncate='True',scaling=scl,detrend='linear', 
                                     window=wdws,window_correction=wdw_cor)
# Out:
# CPU times: user 1min 35s, sys: 39 s, total: 2min 14s
# Wall time: 9min 11s

# %%
N2r=(5.2*10**-3)**2

# %%
Epe_full=(1/(2*N2r))*Bf

# %%
Epe_full.to_netcdf('/homes/metogra/iufarias/Documents/data/spec/100_int/KE/Epe_full.nc')

# %% [markdown]
# #### EPE (SMTH)

# %%
rho_smth_psi=dt.rho.xroms.to_grid('psi', 's_rho')
rho_smth_interp=rho_smth_psi.xroms.isoslice(np.linspace(-5,-50, 10))[:,:,120:-120,120:800]

# %%
b_smth_interp=xroms.buoyancy(rho_smth_interp)

# %%
# %%time
with ProgressBar():
    Bt=xrft.isotropic_power_spectrum(b_smth_interp,
                                      dim=['eta_v','xi_u'],
                              nfactor=nf,truncate='True',scaling=scl,detrend='linear', 
                                     window=wdws,window_correction=wdw_cor)
# Out:
# CPU times: user 1min 26s, sys: 34.4 s, total: 2min 1s
# Wall time: 9min 23s

# %%
Epe_smth=(1/(2*N2r))*Bt

# %%
Epe_smth.to_netcdf('/homes/metogra/iufarias/Documents/data/spec/100_int/KE/Epe_smth.nc')

# %% [markdown]
# #### w'b' (FULL)

# %%
w_full_psi=df.w.xroms.to_grid('psi', 's_rho')
w_full_interp=w_full_psi.xroms.isoslice(np.linspace(-5,-50, 10))[:,:,120:-120,120:800]

# %%
# %%time

with ProgressBar():
    wb_f=xrft.isotropic_cross_spectrum(w_full_interp,b_full_interp,
                                      dim=['eta_v','xi_u'],
                              nfactor=nf,truncate='True',scaling=scl,detrend='linear', 
                                     window=wdws,window_correction=wdw_cor).real
# Out:
# CPU times: user 2min 38s, sys: 1min 3s, total: 3min 42s
# Wall time: 17min 58s

# %%
w_smth_psi=dt.w.xroms.to_grid('psi', 's_rho')
w_smth_interp=w_smth_psi.xroms.isoslice(np.linspace(-5,-50, 10))[:,:,120:-120,120:800]

# %%
# %%time

with ProgressBar():
    wb_t=xrft.isotropic_cross_spectrum(w_smth_interp,b_smth_interp,
                                      dim=['eta_v','xi_u'],
                              nfactor=nf,truncate='True',scaling=scl,detrend='linear', 
                                     window=wdws,window_correction=wdw_cor).real
# Out:
# CPU times: user 2min 10s, sys: 52.6 s, total: 3min 2s
# Wall time: 14min 36s

# %%
wb_f.to_netcdf('/homes/metogra/iufarias/Documents/data/spec/100_int/KE/wb_full.nc')
wb_t.to_netcdf('/homes/metogra/iufarias/Documents/data/spec/100_int/KE/wb_smth.nc')

# %%
# AA=xr.open_dataarray('/homes/metogra/iufarias/Documents/data/spec/100_int/KE/wb_full_01.nc')
# BB=xr.open_dataarray('/homes/metogra/iufarias/Documents/data/spec/100_int/KE/wb_smth_01.nc')

# %%
# fig,ax=plt.subplots(2,1,figsize=(9,6))


# im1=ax[0].pcolormesh(AA.freq_r/dx,AA.z_rho_psi,AA.mean(axis=0)/dx*1e3,
#                vmin=0,vmax=6e-5,cmap='inferno')
# ax[0].set_xscale('log')
# ax[0].set_xlim(1e-2,0)
# ax[0].set_title(r'(a)',color='k',fontsize=20)
# # ax[0].set_ylabel('Depth [m]',fontsize=20,x=0.1)



# im2=ax[1].pcolormesh(BB.freq_r/dx,BB.z_rho_psi,BB.mean(axis=0)/dx*1e3,
#                vmin=0,vmax=6e-5,cmap='inferno')
# ax[1].set_xscale('log')
# ax[1].set_xlim(1e-2,0)
# ax[1].set_title(r'(b)',fontsize=20)
# # ax[1].set_ylabel('Depth [m]',fontsize=20,x=0.1)
# fig.supylabel('Depth [m]',fontsize=20)
# fig.supxlabel(r'Wavenumber [km$^{-1}$]',fontweight='bold',fontsize=20,y=-0.00001)
    

    
# fig.subplots_adjust(right=0.8,hspace=0.4)
# cbar_ax = fig.add_axes([0.85, 0.15, 0.05, 0.7])
# cbar=fig.colorbar(im, cax=cbar_ax)
# # cbar=fig.colorbar(im,cax=ax[0]
# cbar.set_label(r'Spectral Density [m$^3\,$s$^{-3}$]',labelpad=12)

# # plt.tight_layout()
# plt.savefig('/homes/metogra/iufarias/Documents/figures/2_CROCO/CROCO_zintegrated/z_int/wb_z.png')

# %% [markdown]
# #### b and w specta (FULL and SMTH)

# %%
# %%time
# with ProgressBar():
#     Bf=xrft.isotropic_power_spectrum(b_full_interp,
#                                       dim=['eta_v','xi_u'],
#                               nfactor=nf,truncate='True',scaling=scl,detrend='linear', 
#                                      window=wdws,window_correction=wdw_cor)

#     Bt=xrft.isotropic_power_spectrum(b_smth_interp),
#                                       dim=['eta_v','xi_u'],
#                               nfactor=nf,truncate='True',scaling=scl,detrend='linear', 
#                                      window=wdws,window_correction=wdw_cor)

#     Wf=xrft.isotropic_power_spectrum(w_full_interp),
#                                       dim=['eta_v','xi_u'],
#                               nfactor=nf,truncate='True',scaling=scl,detrend='linear', 
#                                      window=wdws,window_correction=wdw_cor)

#     Wt=xrft.isotropic_power_spectrum(w_smth_interp),
#                                       dim=['eta_v','xi_u'],
#                               nfactor=nf,truncate='True',scaling=scl,detrend='linear', 
#                                      window=wdws,window_correction=wdw_cor)
