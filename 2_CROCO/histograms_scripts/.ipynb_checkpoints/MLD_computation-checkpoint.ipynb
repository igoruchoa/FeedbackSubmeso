# %%
import numpy as np
import xroms
from glob import glob
import matplotlib.pyplot as plt
import gc
import xarray as xr
import pandas as pd
import xrft as xrft
import warnings
import sys
import xrft
# import seaborn as sns
sys.path.append("/homes/metogra/iufarias/FeedbackSubmeso/useful/")
import romspickle

from dask.diagnostics import ProgressBar
import dask
# dask.config.set(**{'array.slicing.split_large_chunks': True})
from dask.distributed import Client, LocalCluster

import scipy.integrate as integ
warnings.filterwarnings("ignore")
# Out:
# /homes/metogra/iufarias/xroms/xroms/interp.py:18: UserWarning: xESMF is not installed, so `interpll` will not run.
#   warnings.warn("xESMF is not installed, so `interpll` will not run.")

# %%
def calc_MLD(dens_int,fillna=2e20,thresh=0.125,coo='z_rho'):
    '''
    dens_int: Interpolated density xarray (from xroms.isoslice)
    '''
    if coo in dens_int.dims:            
        dens_int_new=dens_int.dropna(coo)
        zdic={'{0}'.format(coo):0}
        mld_dens = dens_int_new.isel(zdic)  + thresh
        
        z_indexes = (abs(dens_int_new - mld_dens)).fillna(fillna).argmin(coo)
        mld_f = dens_int_new[coo][z_indexes]
    else:
        print('z_rho dimension not found')
    
    return mld_f

# %%
client = Client(n_workers=90)
# client = Client(cluster)
# Out:
# 2023-08-17 13:28:39,804 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-70tk375p', purging
# 2023-08-17 13:28:39,804 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-dqgc87pp', purging
# 2023-08-17 13:28:39,805 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-qxs_1ssj', purging
# 2023-08-17 13:28:39,805 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-lhkcc294', purging
# 2023-08-17 13:28:39,805 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-h4cvzj1d', purging
# 2023-08-17 13:28:39,805 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-24c_zzc1', purging
# 2023-08-17 13:28:39,805 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-4bjmvd7r', purging
# 2023-08-17 13:28:39,806 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-mfv6c00c', purging
# 2023-08-17 13:28:39,806 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-ru8qwxr0', purging
# 2023-08-17 13:28:39,806 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-7_hm7gu2', purging
# 2023-08-17 13:28:39,806 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-n24qt1nd', purging
# 2023-08-17 13:28:39,806 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-mvd9chro', purging
# 2023-08-17 13:28:39,806 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-33jsvb_b', purging
# 2023-08-17 13:28:39,807 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-4b5efy3s', purging
# 2023-08-17 13:28:39,807 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-cph7368k', purging
# 2023-08-17 13:28:39,807 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-kd89jj73', purging
# 2023-08-17 13:28:39,807 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-pqq9zso5', purging
# 2023-08-17 13:28:39,807 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-1yvysezb', purging
# 2023-08-17 13:28:39,807 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-3c2csnj6', purging
# 2023-08-17 13:28:39,808 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-snjh93xx', purging
# 2023-08-17 13:28:39,808 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-z10k5l2z', purging
# 2023-08-17 13:28:39,808 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-rf8z9p5k', purging
# 2023-08-17 13:28:39,808 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-eqsvt75i', purging
# 2023-08-17 13:28:39,808 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-wz_ulkuy', purging
# 2023-08-17 13:28:39,808 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-levwxjvl', purging
# 2023-08-17 13:28:39,808 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-ee9cdduh', purging
# 2023-08-17 13:28:39,808 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-nscfbnw9', purging
# 2023-08-17 13:28:39,809 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-mnbebzra', purging
# 2023-08-17 13:28:39,809 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-l_27vg3z', purging
# 2023-08-17 13:28:39,809 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-dzpw445q', purging
# 2023-08-17 13:28:39,809 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-r5507t5f', purging
# 2023-08-17 13:28:39,809 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-q9xcih5t', purging
# 2023-08-17 13:28:39,809 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-hizu9b9p', purging
# 2023-08-17 13:28:39,809 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-4p2_wxir', purging
# 2023-08-17 13:28:39,810 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-7h0vmt_7', purging
# 2023-08-17 13:28:39,810 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-fpra5sxe', purging
# 2023-08-17 13:28:39,810 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-f37qt1t2', purging
# 2023-08-17 13:28:39,810 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-jmgbr1bf', purging
# 2023-08-17 13:28:39,810 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-ht0lh4ip', purging
# 2023-08-17 13:28:39,810 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-y7ytjdzz', purging
# 2023-08-17 13:28:39,810 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-zidje_bg', purging
# 2023-08-17 13:28:39,811 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-52fg1p9b', purging
# 2023-08-17 13:28:39,811 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-5i4_eu_q', purging
# 2023-08-17 13:28:39,811 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-pxndv178', purging
# 2023-08-17 13:28:39,811 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-reygwcdf', purging
# 2023-08-17 13:28:39,811 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-a6urbs8q', purging
# 2023-08-17 13:28:39,811 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-lr2k7igd', purging
# 2023-08-17 13:28:39,811 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-v8gmap0f', purging
# 2023-08-17 13:28:39,811 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-hhzx3nt6', purging
# 2023-08-17 13:28:39,812 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-rix1dy9u', purging
# 2023-08-17 13:28:39,812 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-fdpnmt_q', purging
# 2023-08-17 13:28:39,812 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-6id6hesu', purging
# 2023-08-17 13:28:39,812 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-rs2uy0ya', purging
# 2023-08-17 13:28:39,812 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-msrdy8ev', purging
# 2023-08-17 13:28:39,812 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-s_46cgp8', purging
# 2023-08-17 13:28:39,812 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-1ef1clga', purging
# 2023-08-17 13:28:39,813 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-aq24_01q', purging
# 2023-08-17 13:28:39,813 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-45u6zkjl', purging
# 2023-08-17 13:28:39,813 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-h6rhs09l', purging
# 2023-08-17 13:28:39,813 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-vb5ga9fk', purging
# 2023-08-17 13:28:39,813 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-39zbg6n6', purging
# 2023-08-17 13:28:39,813 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-ndcwj4rv', purging
# 2023-08-17 13:28:39,813 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-6tzwwoya', purging
# 2023-08-17 13:28:39,813 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-qe7q3u_q', purging
# 2023-08-17 13:28:39,814 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-102b6xv2', purging
# 2023-08-17 13:28:39,814 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-q65uqo0p', purging
# 2023-08-17 13:28:39,814 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-4lrc4bd0', purging
# 2023-08-17 13:28:39,814 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-kzy0tvhs', purging
# 2023-08-17 13:28:39,814 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-d0p2m28g', purging
# 2023-08-17 13:28:39,814 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-jyigabiy', purging
# 2023-08-17 13:28:39,814 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-uud_w91r', purging
# 2023-08-17 13:28:39,815 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-wzyae8ga', purging
# 2023-08-17 13:28:39,815 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-2cw53567', purging
# 2023-08-17 13:28:39,815 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-_8yfp2wi', purging
# 2023-08-17 13:28:39,815 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-dj7w2cmf', purging
# 2023-08-17 13:28:39,815 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-_fb08eih', purging
# 2023-08-17 13:28:39,815 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-gifulahf', purging
# 2023-08-17 13:28:39,815 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-nxliqmyk', purging
# 2023-08-17 13:28:39,815 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-0uqln6qz', purging
# 2023-08-17 13:28:39,816 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-7sri7rl1', purging
# 2023-08-17 13:28:39,816 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-t_wlwpss', purging
# 2023-08-17 13:28:39,816 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-0cp6l7p2', purging
# 2023-08-17 13:28:39,816 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-kqbbkn8z', purging
# 2023-08-17 13:28:39,816 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-ie4szsf3', purging
# 2023-08-17 13:28:39,816 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-tpagjk2x', purging
# 2023-08-17 13:28:39,816 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-zff7w_cn', purging
# 2023-08-17 13:28:39,816 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-1jt2ij00', purging
# 2023-08-17 13:28:39,817 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-c2x5t59f', purging
# 2023-08-17 13:28:39,817 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-gudzbzuy', purging
# 2023-08-17 13:28:39,817 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-lh3fu2tp', purging

# %%
client
# Out:
# <Client: 'tcp://127.0.0.1:40710' processes=90 threads=180, memory=503.40 GiB>

# %% [markdown]
# ## Reading CROCO (3D)

# %%
# chunks={'time_counter':10, 'x_rho':50, 'y_rho':190,'s_rho':80,'s_w':80}
chunks={'time_counter':1,'x_rho':1000,"x_u":1000,"x_v":1000,
                        'y_rho':1520,"y_u":1520,"y_v":1520,'s_rho':80,'s_w':80}


path='/data/pacific/lrenault/SASI/CROCO/'

# varf=xr.open_mfdataset(path + 'FULL/SASI*2012-01*.nc',data_vars='minimal',chunks=chunks)
# vart=xr.open_mfdataset(path + 'SMTH/SASI*2012-01*.nc',data_vars='minimal',chunks=chunks)

varf=xr.open_mfdataset(path + 'FULL/SASI*2012*.nc',data_vars='minimal',chunks=chunks)
vart=xr.open_mfdataset(path + 'SMTH/SASI*2012*.nc',data_vars='minimal',chunks=chunks)

# %%
varx = varf.rename({"time_counter":"ocean_time","x_rho": "xi_rho","x_u":"xi_u","x_v":"xi_v","x_w":"xi_w",
                    "y_rho":"eta_rho","y_v":"eta_v","y_u":"eta_u","y_w":"eta_w","s_rho":"s_rho","s_w":"s_w"})
df,gf=xroms.roms_dataset(varx,Vtransform=varx.Vtransform.data)

vary = vart.rename({"time_counter":"ocean_time","x_rho": "xi_rho","x_u":"xi_u","x_v":"xi_v",
                    "y_rho":"eta_rho","y_v":"eta_v","y_u":"eta_u","y_w":"eta_w","s_rho":"s_rho","s_w":"s_w"})
dt,gt=xroms.roms_dataset(vary,Vtransform=vary.Vtransform.data)

# %%
plt.rcParams['text.usetex'] = True
plt.rcParams.update({'font.size': 22})

plt.rcParams['font.family'] = 'sans-serif'
plt.rcParams['font.sans-serif'] = ['Lucida Grande']

# %%
timer_h=pd.DatetimeIndex(dt.ocean_time)
timer_d=pd.DatetimeIndex(dt.ocean_time.groupby("ocean_time.dayofyear").mean())

# %%
rho_full=df.rho[:,:,120:-120,120:800]
rho_smth=dt.rho[:,:,120:-120,120:800]

# %%
z_interp=np.linspace(-1,-200, 100)

# %%
z=rho_full.z_rho0.compute()

# %%
day_x=10

# %%
# %%time
rho_full_interp=rho_full[day_x,:,:,:].xroms.isoslice(z_interp).compute()
# Out:
# CPU times: user 2.85 s, sys: 1.62 s, total: 4.47 s
# Wall time: 10.3 s

# %%
mld_rho=calc_MLD(rho_full_interp)
mld_kpp=varf.hbl[day_x,120:-120,120:800]

# %%
df.hbl[day_x,120:-120,120:800].plot(vmin=0,vmax=100,cmap='jet')

# %%
(-calc_MLD(rho_full_interp)).plot(vmin=0,vmax=100,cmap='jet')

# %%
loc_y=250
loc_x=5
plt.figure(figsize=(8,4))
plt.subplot(1,2,1)
rho_full_interp[:,loc_y,loc_x].plot(y='z_rho')
plt.plot([0,2],[mld_rho[loc_y,loc_x],mld_rho[loc_y,loc_x]])

plt.plot([0,2],[-mld_kpp[loc_y,loc_x],-mld_kpp[loc_y,loc_x]])
plt.xlim(-0.01+rho_full_interp[1,loc_y,loc_x],rho_full_interp[1,loc_y,loc_x]+0.125)
# plt.xlim(0.15,0.3)


plt.title('')
plt.subplot(1,2,2)
rho_full_interp[:,loc_y,loc_x].plot(y='z_rho')
plt.plot([0,2],[mld_rho[loc_y,loc_x],mld_rho[loc_y,loc_x]])

plt.plot([0,2],[-mld_kpp[loc_y,loc_x],-mld_kpp[loc_y,loc_x]])
# plt.xlim(-0.01+rho_full_interp[0,loc_y,loc_x],rho_full_interp[0,loc_y,loc_x]+0.125)
plt.title('')
# Out:
# Text(0.5, 1.0, '')

# %%
dec=2
MLD_full=xr.DataArray(coords=(df.ocean_time[::dec],
                         range(df.rho[:,:,120:-120,120:800].shape[2]),
                         range(df.rho[:,:,120:-120,120:800].shape[3])),
                      dims=['ocean_time','eta_rho','xi_rho'])
MLD_smth=xr.DataArray(coords=(dt.ocean_time[::dec],
                         range(df.rho[:,:,120:-120,120:800].shape[2]),
                         range(df.rho[:,:,120:-120,120:800].shape[3])),
                      dims=['ocean_time','eta_rho','xi_rho'])

# %%
# %%time
for ix in range(df.rho[::dec].shape[0]):
    rho_full_interp_d=rho_full[::dec][ix].xroms.isoslice(z_interp).compute()
    MLD_full[ix,:,:]=(-calc_MLD(rho_full_interp_d)).data
# Out:
# CPU times: user 22min 35s, sys: 13min 50s, total: 36min 26s
# Wall time: 1h 13min 5s

# %%
MLD_full.to_netcdf('/homes/metogra/iufarias/Documents/data/MLD/MLD_full_maps.nc','w')

# %%
MLD_full=xr.open_dataset('/homes/metogra/iufarias/Documents/data/MLD/MLD_full_maps.nc')['__xarray_dataarray_variable__']

# %%
# %%time
for ix in range(dt.rho[::dec].shape[0]):
    rho_smth_interp_d=rho_smth[::dec][ix].xroms.isoslice(z_interp).compute()

    MLD_smth[ix,:,:]=(-calc_MLD(rho_smth_interp_d)).data
# Out:
# CPU times: user 17min 14s, sys: 11min 29s, total: 28min 43s
# Wall time: 52min 19s

# %%
ix
# Out:
# 363

# %%
MLD_smth.to_netcdf('/homes/metogra/iufarias/Documents/data/MLD/MLD_smth_maps.nc')

# %%
dbool=True
slog=True

a1=0.8
a2=0.4
lw=2
HT='step'

plt.figure(figsize=(10,10))
plt.hist(np.ravel((MLD_full)),bins=100,color='tomato',linewidth=lw,histtype=HT,alpha=a2,density=dbool,log=slog)
plt.hist(np.ravel((MLD_smth)),bins=100,color='cornflowerblue',linewidth=lw,histtype=HT,alpha=a1,density=dbool,log=slog)
plt.xlabel(r'$MLD$[m]')

plt.xlim(2,70)
plt.tight_layout()
# plt.savefig(
