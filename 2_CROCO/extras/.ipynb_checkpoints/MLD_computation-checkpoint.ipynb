# %%
import numpy as np
import xroms
from glob import glob
import matplotlib.pyplot as plt
import gc
import xarray as xr
import pandas as pd
import xrft as xrft
import warnings
import sys
import xrft
# import seaborn as sns
sys.path.append("/homes/metogra/iufarias/FeedbackSubmeso/useful/")
import romspickle

from dask.diagnostics import ProgressBar
import dask
# dask.config.set(**{'array.slicing.split_large_chunks': True})
from dask.distributed import Client, LocalCluster

import scipy.integrate as integ
warnings.filterwarnings("ignore")
# Out:
# /homes/metogra/iufarias/xroms/xroms/interp.py:18: UserWarning: xESMF is not installed, so `interpll` will not run.
#   warnings.warn("xESMF is not installed, so `interpll` will not run.")

# %%
def calc_MLD(dens_int,fillna=2e20,thresh=0.125,coo='z_rho'):
    '''
    dens_int: Interpolated density xarray (from xroms.isoslice)
    '''
    if coo in dens_int.dims:            
        dens_int_new=dens_int.dropna(coo)
        zdic={'{0}'.format(coo):0}
        mld_dens = dens_int_new.isel(zdic)  + thresh
        
        z_indexes = (abs(dens_int_new - mld_dens)).fillna(fillna).argmin(coo)
        mld_f = dens_int_new[coo][z_indexes]
    else:
        print('z_rho dimension not found')
    
    return mld_f

# %%
client = Client(n_workers=90)
# client = Client(cluster)
# Out:
# 2023-08-16 15:37:37,784 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-5fyf9_51', purging
# 2023-08-16 15:37:37,785 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-oihmothv', purging
# 2023-08-16 15:37:37,785 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-1y618uub', purging
# 2023-08-16 15:37:37,785 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-sihb6p8u', purging
# 2023-08-16 15:37:37,786 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-bd587aus', purging
# 2023-08-16 15:37:37,787 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-m2sr0ktk', purging
# 2023-08-16 15:37:37,787 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-zo2_n0z2', purging
# 2023-08-16 15:37:37,787 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-olsvn467', purging
# 2023-08-16 15:37:37,788 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-qup1t6a8', purging
# 2023-08-16 15:37:37,788 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-ba_e6kf0', purging
# 2023-08-16 15:37:37,789 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-plr5q00k', purging
# 2023-08-16 15:37:37,789 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-qvax91wr', purging
# 2023-08-16 15:37:37,790 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-rfyn2owh', purging
# 2023-08-16 15:37:37,790 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-nsw6jqyv', purging
# 2023-08-16 15:37:37,790 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-zwhhne7h', purging
# 2023-08-16 15:37:37,791 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-82m8tp28', purging
# 2023-08-16 15:37:37,791 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-a__xi81z', purging
# 2023-08-16 15:37:37,792 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-qn0mizrp', purging
# 2023-08-16 15:37:37,792 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-nwxaab39', purging
# 2023-08-16 15:37:37,792 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-k85zhi6w', purging
# 2023-08-16 15:37:37,792 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-3qcxnj72', purging
# 2023-08-16 15:37:37,793 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-7t4z6ekt', purging
# 2023-08-16 15:37:37,793 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-941memxd', purging
# 2023-08-16 15:37:37,793 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-ai_neajo', purging
# 2023-08-16 15:37:37,793 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-qy_qx1qo', purging
# 2023-08-16 15:37:37,793 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-pjckx61j', purging
# 2023-08-16 15:37:37,794 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-o1q_szx5', purging
# 2023-08-16 15:37:37,794 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-goe1yl_l', purging
# 2023-08-16 15:37:37,794 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-m0ynycb4', purging
# 2023-08-16 15:37:37,794 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-s2vess3i', purging
# 2023-08-16 15:37:37,794 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-y974tc66', purging
# 2023-08-16 15:37:37,794 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-9lqd99g5', purging
# 2023-08-16 15:37:37,795 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-jujtw7hs', purging
# 2023-08-16 15:37:37,795 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-dzl46yfl', purging
# 2023-08-16 15:37:37,795 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-0c8wqr18', purging
# 2023-08-16 15:37:37,795 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-z67g07z7', purging
# 2023-08-16 15:37:37,795 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-x693ht5t', purging
# 2023-08-16 15:37:37,796 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-3ctlk55s', purging
# 2023-08-16 15:37:37,796 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-wv9iv80a', purging
# 2023-08-16 15:37:37,796 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-uc7snpxg', purging
# 2023-08-16 15:37:37,796 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-4jzagxxt', purging
# 2023-08-16 15:37:37,796 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-uoexqcxj', purging
# 2023-08-16 15:37:37,797 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-y2jvlgvf', purging
# 2023-08-16 15:37:37,797 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-_e31xxoe', purging
# 2023-08-16 15:37:37,797 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-dqh9t9tb', purging
# 2023-08-16 15:37:37,797 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-n2bpu7b3', purging
# 2023-08-16 15:37:37,798 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-8wg0_5re', purging
# 2023-08-16 15:37:37,798 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-dq7mhgue', purging
# 2023-08-16 15:37:37,798 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-v5ipugzj', purging
# 2023-08-16 15:37:37,798 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-temvdihi', purging
# 2023-08-16 15:37:37,798 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-l50tsine', purging
# 2023-08-16 15:37:37,798 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-_v6ofogw', purging
# 2023-08-16 15:37:37,799 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-1952luzn', purging
# 2023-08-16 15:37:37,799 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-pb3uj3z7', purging
# 2023-08-16 15:37:37,799 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-m4rg7lvp', purging
# 2023-08-16 15:37:37,799 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-nqbg7n31', purging
# 2023-08-16 15:37:37,800 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-ayo3n7a4', purging
# 2023-08-16 15:37:37,800 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-fdarnpv3', purging
# 2023-08-16 15:37:37,800 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-hb7f6dv0', purging
# 2023-08-16 15:37:37,800 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-zu_x0z4h', purging
# 2023-08-16 15:37:37,800 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-53tmvnqd', purging
# 2023-08-16 15:37:37,801 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-19e46gv7', purging
# 2023-08-16 15:37:37,801 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-e00ddx6b', purging
# 2023-08-16 15:37:37,801 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-q_j9k485', purging
# 2023-08-16 15:37:37,801 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-wy3d0d2y', purging
# 2023-08-16 15:37:37,801 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-ufqyj001', purging
# 2023-08-16 15:37:37,801 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-quy__6iw', purging
# 2023-08-16 15:37:37,802 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-t19njv3r', purging
# 2023-08-16 15:37:37,802 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-n23fsetd', purging
# 2023-08-16 15:37:37,802 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-b7czdpcu', purging
# 2023-08-16 15:37:37,802 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-eurmjgkt', purging
# 2023-08-16 15:37:37,802 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-8lb2f3wr', purging
# 2023-08-16 15:37:37,802 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-h5voo2c1', purging
# 2023-08-16 15:37:37,803 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-ym7ot84x', purging
# 2023-08-16 15:37:37,803 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-butkd5kc', purging
# 2023-08-16 15:37:37,803 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-ti73sley', purging
# 2023-08-16 15:37:37,803 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-9w15qhqp', purging
# 2023-08-16 15:37:37,803 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-hlohap0z', purging
# 2023-08-16 15:37:37,804 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-26o22fwz', purging
# 2023-08-16 15:37:37,804 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-gx0r8_8b', purging
# 2023-08-16 15:37:37,804 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-4taeagtd', purging
# 2023-08-16 15:37:37,804 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-ffe66zg4', purging
# 2023-08-16 15:37:37,805 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-7udvm9bg', purging
# 2023-08-16 15:37:37,805 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-jxsvdyyo', purging
# 2023-08-16 15:37:37,805 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-75th2hgl', purging
# 2023-08-16 15:37:37,806 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-1sergf3y', purging
# 2023-08-16 15:37:37,806 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-aa0_a304', purging
# 2023-08-16 15:37:37,806 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-0oz2zf6r', purging
# 2023-08-16 15:37:37,806 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-p2q6su47', purging
# 2023-08-16 15:37:37,807 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-z30ntq_v', purging

# %%
client
# Out:
# <Client: 'tcp://127.0.0.1:40978' processes=90 threads=180, memory=503.40 GiB>

# %% [markdown]
# ## Reading CROCO (3D)

# %%
# chunks={'time_counter':10, 'x_rho':50, 'y_rho':190,'s_rho':80,'s_w':80}
chunks={'time_counter':1,'x_rho':1000,"x_u":1000,"x_v":1000,
                        'y_rho':1520,"y_u":1520,"y_v":1520,'s_rho':80,'s_w':80}


path='/data/pacific/lrenault/SASI/CROCO/'

# varf=xr.open_mfdataset(path + 'FULL/SASI*2012-01*.nc',data_vars='minimal',chunks=chunks)
# vart=xr.open_mfdataset(path + 'SMTH/SASI*2012-01*.nc',data_vars='minimal',chunks=chunks)

varf=xr.open_mfdataset(path + 'FULL/SASI*2012*.nc',data_vars='minimal',chunks=chunks)
vart=xr.open_mfdataset(path + 'SMTH/SASI*2012*.nc',data_vars='minimal',chunks=chunks)

# %%
varx = varf.rename({"time_counter":"ocean_time","x_rho": "xi_rho","x_u":"xi_u","x_v":"xi_v","x_w":"xi_w",
                    "y_rho":"eta_rho","y_v":"eta_v","y_u":"eta_u","y_w":"eta_w","s_rho":"s_rho","s_w":"s_w"})
df,gf=xroms.roms_dataset(varx,Vtransform=varx.Vtransform.data)

vary = vart.rename({"time_counter":"ocean_time","x_rho": "xi_rho","x_u":"xi_u","x_v":"xi_v",
                    "y_rho":"eta_rho","y_v":"eta_v","y_u":"eta_u","y_w":"eta_w","s_rho":"s_rho","s_w":"s_w"})
dt,gt=xroms.roms_dataset(vary,Vtransform=vary.Vtransform.data)

# %%
plt.rcParams['text.usetex'] = True
plt.rcParams.update({'font.size': 22})

plt.rcParams['font.family'] = 'sans-serif'
plt.rcParams['font.sans-serif'] = ['Lucida Grande']

# %%
timer_h=pd.DatetimeIndex(dt.ocean_time)
timer_d=pd.DatetimeIndex(dt.ocean_time.groupby("ocean_time.dayofyear").mean())

# %%
rho_full=df.rho[:,:,120:-120,120:800]
rho_smth=dt.rho[:,:,120:-120,120:800]

# %%
z_interp=np.linspace(-1,-200, 20)

# %%
z=rho_full.z_rho0.compute()

# %%
day_x=10

# %%
# %%time
rho_full_interp=rho_full[day_x,:,:,:].xroms.isoslice(z_interp).compute()
# Out:
# CPU times: user 2.42 s, sys: 989 ms, total: 3.41 s
# Wall time: 8.58 s

# %%
mld_rho=calc_MLD(rho_full_interp)
mld_kpp=varf.hbl[day_x,120:-120,120:800]

# %%
df.hbl[day_x,120:-120,120:800].plot(vmin=0,vmax=100,cmap='jet')

# %%
(-calc_MLD(rho_full_interp)).plot(vmin=0,vmax=100,cmap='jet')

# %%
loc_y=250
loc_x=5
plt.figure(figsize=(8,4))
plt.subplot(1,2,1)
rho_full_interp[:,loc_y,loc_x].plot(y='z_rho')
plt.plot([0,2],[mld_rho[loc_y,loc_x],mld_rho[loc_y,loc_x]])

plt.plot([0,2],[-mld_kpp[loc_y,loc_x],-mld_kpp[loc_y,loc_x]])
plt.xlim(-0.01+rho_full_interp[1,loc_y,loc_x],rho_full_interp[1,loc_y,loc_x]+0.125)
# plt.xlim(0.15,0.3)


plt.title('')
plt.subplot(1,2,2)
rho_full_interp[:,loc_y,loc_x].plot(y='z_rho')
plt.plot([0,2],[mld_rho[loc_y,loc_x],mld_rho[loc_y,loc_x]])

plt.plot([0,2],[-mld_kpp[loc_y,loc_x],-mld_kpp[loc_y,loc_x]])
# plt.xlim(-0.01+rho_full_interp[0,loc_y,loc_x],rho_full_interp[0,loc_y,loc_x]+0.125)
plt.title('')
# Out:
# Text(0.5, 1.0, '')

# %%
dec=2
MLD_full=xr.DataArray(coords=(df.ocean_time[::dec],
                         range(df.rho[:,:,120:-120,120:800].shape[2]),
                         range(df.rho[:,:,120:-120,120:800].shape[3])),
                      dims=['ocean_time','eta_rho','xi_rho'])
MLD_smth=xr.DataArray(coords=(dt.ocean_time[::dec],
                         range(df.rho[:,:,120:-120,120:800].shape[2]),
                         range(df.rho[:,:,120:-120,120:800].shape[3])),
                      dims=['ocean_time','eta_rho','xi_rho'])

# %%
# %%time
for ix in range(df.rho[::dec].shape[0]):
    rho_full_interp_d=rho_full[::dec][ix].xroms.isoslice(z_interp).compute()
    MLD_full[ix,:,:]=(-calc_MLD(rho_full_interp_d)).data
# Out:
# CPU times: user 10min 12s, sys: 4min 32s, total: 14min 45s
# Wall time: 30min 28s

# %%
MLD_full.to_netcdf('/homes/metogra/iufarias/Documents/data/MLD/MLD_full_maps.nc')

# %%
MLD_full=xr.open_dataset('/homes/metogra/iufarias/Documents/data/MLD/MLD_full_maps.nc')['__xarray_dataarray_variable__']

# %%
# %%time
for ix in range(dt.rho[::dec].shape[0]):
    rho_smth_interp_d=rho_smth[::dec][ix].xroms.isoslice(z_interp).compute()

    MLD_smth[ix,:,:]=(-calc_MLD(rho_smth_interp_d)).data
# Out:
# 2023-08-16 17:28:17,629 - distributed.nanny - ERROR - Worker process died unexpectedly
# 2023-08-16 17:28:17,630 - distributed.nanny - ERROR - Worker process died unexpectedly
# 2023-08-16 17:28:17,630 - distributed.nanny - ERROR - Worker process died unexpectedly
# 2023-08-16 17:28:17,630 - distributed.nanny - ERROR - Worker process died unexpectedly
# 2023-08-16 17:28:17,630 - distributed.nanny - ERROR - Worker process died unexpectedly
# 2023-08-16 17:28:17,630 - distributed.nanny - ERROR - Worker process died unexpectedly
# 2023-08-16 17:28:17,630 - distributed.nanny - ERROR - Worker process died unexpectedly
# 2023-08-16 17:28:17,631 - distributed.nanny - ERROR - Worker process died unexpectedly
# 2023-08-16 17:28:17,631 - distributed.nanny - ERROR - Worker process died unexpectedly
# 2023-08-16 17:28:17,631 - distributed.nanny - ERROR - Worker process died unexpectedly
# 2023-08-16 17:28:17,631 - distributed.nanny - ERROR - Worker process died unexpectedly
# 2023-08-16 17:28:17,631 - distributed.nanny - ERROR - Worker process died unexpectedly
# 2023-08-16 17:28:17,631 - distributed.nanny - ERROR - Worker process died unexpectedly
# 2023-08-16 17:28:17,631 - distributed.nanny - ERROR - Worker process died unexpectedly
# 2023-08-16 17:28:17,631 - distributed.nanny - ERROR - Worker process died unexpectedly
# 2023-08-16 17:28:17,631 - distributed.nanny - ERROR - Worker process died unexpectedly
# 2023-08-16 17:28:17,631 - distributed.nanny - ERROR - Worker process died unexpectedly
# 2023-08-16 17:28:17,632 - distributed.nanny - ERROR - Worker process died unexpectedly
# 2023-08-16 17:28:17,632 - distributed.nanny - ERROR - Worker process died unexpectedly
# 2023-08-16 17:28:17,632 - distributed.nanny - ERROR - Worker process died unexpectedly
# 2023-08-16 17:28:17,632 - distributed.nanny - ERROR - Worker process died unexpectedly
# 2023-08-16 17:28:17,632 - distributed.nanny - ERROR - Worker process died unexpectedly
# 2023-08-16 17:28:17,632 - distributed.nanny - ERROR - Worker process died unexpectedly
# 2023-08-16 17:28:17,632 - distributed.nanny - ERROR - Worker process died unexpectedly
# 2023-08-16 17:28:17,632 - distributed.nanny - ERROR - Worker process died unexpectedly
# 2023-08-16 17:28:17,632 - distributed.nanny - ERROR - Worker process died unexpectedly
# 2023-08-16 17:28:17,632 - distributed.nanny - ERROR - Worker process died unexpectedly
# 2023-08-16 17:28:17,632 - distributed.nanny - ERROR - Worker process died unexpectedly
# 2023-08-16 17:28:17,632 - distributed.nanny - ERROR - Worker process died unexpectedly
# 2023-08-16 17:28:17,632 - distributed.nanny - ERROR - Worker process died unexpectedly
# 2023-08-16 17:28:17,633 - distributed.nanny - ERROR - Worker process died unexpectedly
# 2023-08-16 17:28:17,633 - distributed.nanny - ERROR - Worker process died unexpectedly
# 2023-08-16 17:28:17,633 - distributed.nanny - ERROR - Worker process died unexpectedly
# 2023-08-16 17:28:17,633 - distributed.nanny - ERROR - Worker process died unexpectedly
# 2023-08-16 17:28:17,633 - distributed.nanny - ERROR - Worker process died unexpectedly
# 2023-08-16 17:28:17,633 - distributed.nanny - ERROR - Worker process died unexpectedly
# 2023-08-16 17:28:17,633 - distributed.nanny - ERROR - Worker process died unexpectedly
# 2023-08-16 17:28:17,633 - distributed.nanny - ERROR - Worker process died unexpectedly
# 2023-08-16 17:28:17,633 - distributed.nanny - ERROR - Worker process died unexpectedly
# 2023-08-16 17:28:17,633 - distributed.nanny - ERROR - Worker process died unexpectedly
# 2023-08-16 17:28:17,633 - distributed.nanny - ERROR - Worker process died unexpectedly
# 2023-08-16 17:28:17,633 - distributed.nanny - ERROR - Worker process died unexpectedly
# 2023-08-16 17:28:17,633 - distributed.nanny - ERROR - Worker process died unexpectedly
# 2023-08-16 17:28:17,633 - distributed.nanny - ERROR - Worker process died unexpectedly
# 2023-08-16 17:28:17,633 - distributed.nanny - ERROR - Worker process died unexpectedly
# 2023-08-16 17:28:17,634 - distributed.nanny - ERROR - Worker process died unexpectedly
# 2023-08-16 17:28:17,634 - distributed.nanny - ERROR - Worker process died unexpectedly
# 2023-08-16 17:28:17,634 - distributed.nanny - ERROR - Worker process died unexpectedly
# 2023-08-16 17:28:17,634 - distributed.nanny - ERROR - Worker process died unexpectedly
# 2023-08-16 17:28:17,634 - distributed.nanny - ERROR - Worker process died unexpectedly
# 2023-08-16 17:28:17,634 - distributed.nanny - ERROR - Worker process died unexpectedly
# 2023-08-16 17:28:17,634 - distributed.nanny - ERROR - Worker process died unexpectedly
# 2023-08-16 17:28:17,634 - distributed.nanny - ERROR - Worker process died unexpectedly
# 2023-08-16 17:28:17,634 - distributed.nanny - ERROR - Worker process died unexpectedly
# 2023-08-16 17:28:17,634 - distributed.nanny - ERROR - Worker process died unexpectedly
# 2023-08-16 17:28:17,634 - distributed.nanny - ERROR - Worker process died unexpectedly
# 2023-08-16 17:28:17,635 - distributed.nanny - ERROR - Worker process died unexpectedly
# 2023-08-16 17:28:17,635 - distributed.nanny - ERROR - Worker process died unexpectedly
# 2023-08-16 17:28:17,635 - distributed.nanny - ERROR - Worker process died unexpectedly
# 2023-08-16 17:28:17,635 - distributed.nanny - ERROR - Worker process died unexpectedly
# 2023-08-16 17:28:17,635 - distributed.nanny - ERROR - Worker process died unexpectedly
# 2023-08-16 17:28:17,635 - distributed.nanny - ERROR - Worker process died unexpectedly
# 2023-08-16 17:28:17,635 - distributed.nanny - ERROR - Worker process died unexpectedly
# 2023-08-16 17:28:17,635 - distributed.nanny - ERROR - Worker process died unexpectedly
# 2023-08-16 17:28:17,635 - distributed.nanny - ERROR - Worker process died unexpectedly
# 2023-08-16 17:28:17,636 - distributed.nanny - ERROR - Worker process died unexpectedly
# 2023-08-16 17:28:17,636 - distributed.nanny - ERROR - Worker process died unexpectedly
# 2023-08-16 17:28:17,636 - distributed.nanny - ERROR - Worker process died unexpectedly
# 2023-08-16 17:28:17,636 - distributed.nanny - ERROR - Worker process died unexpectedly
# 2023-08-16 17:28:17,636 - distributed.nanny - ERROR - Worker process died unexpectedly
# 2023-08-16 17:28:17,637 - distributed.nanny - ERROR - Worker process died unexpectedly
# 2023-08-16 17:28:17,637 - distributed.nanny - ERROR - Worker process died unexpectedly
# 2023-08-16 17:28:17,637 - distributed.nanny - ERROR - Worker process died unexpectedly
# 2023-08-16 17:28:17,637 - distributed.nanny - ERROR - Worker process died unexpectedly
# 2023-08-16 17:28:17,637 - distributed.nanny - ERROR - Worker process died unexpectedly
# 2023-08-16 17:28:17,638 - distributed.nanny - ERROR - Worker process died unexpectedly
# 2023-08-16 17:28:17,638 - distributed.nanny - ERROR - Worker process died unexpectedly
# 2023-08-16 17:28:17,638 - distributed.nanny - ERROR - Worker process died unexpectedly
# 2023-08-16 17:28:17,638 - distributed.nanny - ERROR - Worker process died unexpectedly
# 2023-08-16 17:28:17,638 - distributed.nanny - ERROR - Worker process died unexpectedly
# 2023-08-16 17:28:17,639 - distributed.nanny - ERROR - Worker process died unexpectedly
# 2023-08-16 17:28:17,639 - distributed.nanny - ERROR - Worker process died unexpectedly
# 2023-08-16 17:28:17,639 - distributed.nanny - ERROR - Worker process died unexpectedly
# 2023-08-16 17:28:17,639 - distributed.nanny - ERROR - Worker process died unexpectedly
# 2023-08-16 17:28:17,640 - distributed.nanny - ERROR - Worker process died unexpectedly
# 2023-08-16 17:28:17,640 - distributed.nanny - ERROR - Worker process died unexpectedly
# 2023-08-16 17:28:17,640 - distributed.nanny - ERROR - Worker process died unexpectedly
# 2023-08-16 17:28:17,640 - distributed.nanny - ERROR - Worker process died unexpectedly
# 2023-08-16 17:28:17,645 - distributed.nanny - ERROR - Worker process died unexpectedly
# Task exception was never retrieved
# future: <Task finished name='Task-3087846' coro=<Client._gather.<locals>.wait() done, defined at /homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/client.py:2054> exception=AllExit()>
# Traceback (most recent call last):
#   File "/homes/metogra/iufarias/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/client.py", line 2063, in wait
#     raise AllExit()
# distributed.client.AllExit
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File <timed exec>:2
#
# File ~/miniconda3/envs/XROMS/lib/python3.8/site-packages/xarray/core/dataarray.py:993, in DataArray.compute(self, **kwargs)
#     974 """Manually trigger loading of this array's data from disk or a
#     975 remote source into memory and return a new array. The original is
#     976 left unaltered.
#    (...)
#     990 dask.compute
#     991 """
#     992 new = self.copy(deep=False)
# --> 993 return new.load(**kwargs)
#
# File ~/miniconda3/envs/XROMS/lib/python3.8/site-packages/xarray/core/dataarray.py:967, in DataArray.load(self, **kwargs)
#     949 def load(self: T_DataArray, **kwargs) -> T_DataArray:
#     950     """Manually trigger loading of this array's data from disk or a
#     951     remote source into memory and return this array.
#     952
#    (...)
#     965     dask.compute
#     966     """
# --> 967     ds = self._to_temp_dataset().load(**kwargs)
#     968     new = self._from_temp_dataset(ds)
#     969     self._variable = new._variable
#
# File ~/miniconda3/envs/XROMS/lib/python3.8/site-packages/xarray/core/dataset.py:733, in Dataset.load(self, **kwargs)
#     730 import dask.array as da
#     732 # evaluate all the dask arrays simultaneously
# --> 733 evaluated_data = da.compute(*lazy_data.values(), **kwargs)
#     735 for k, data in zip(lazy_data, evaluated_data):
#     736     self.variables[k].data = data
#
# File ~/miniconda3/envs/XROMS/lib/python3.8/site-packages/dask/base.py:600, in compute(traverse, optimize_graph, scheduler, get, *args, **kwargs)
#     597     keys.append(x.__dask_keys__())
#     598     postcomputes.append(x.__dask_postcompute__())
# --> 600 results = schedule(dsk, keys, **kwargs)
#     601 return repack([f(r, *a) for r, (f, a) in zip(results, postcomputes)])
#
# File ~/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/client.py:3052, in Client.get(self, dsk, keys, workers, allow_other_workers, resources, sync, asynchronous, direct, retries, priority, fifo_timeout, actors, **kwargs)
#    3050         should_rejoin = False
#    3051 try:
# -> 3052     results = self.gather(packed, asynchronous=asynchronous, direct=direct)
#    3053 finally:
#    3054     for f in futures.values():
#
# File ~/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/client.py:2226, in Client.gather(self, futures, errors, direct, asynchronous)
#    2224 else:
#    2225     local_worker = None
# -> 2226 return self.sync(
#    2227     self._gather,
#    2228     futures,
#    2229     errors=errors,
#    2230     direct=direct,
#    2231     local_worker=local_worker,
#    2232     asynchronous=asynchronous,
#    2233 )
#
# File ~/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/utils.py:338, in SyncMethodMixin.sync(self, func, asynchronous, callback_timeout, *args, **kwargs)
#     336     return future
#     337 else:
# --> 338     return sync(
#     339         self.loop, func, *args, callback_timeout=callback_timeout, **kwargs
#     340     )
#
# File ~/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/utils.py:401, in sync(loop, func, callback_timeout, *args, **kwargs)
#     399 else:
#     400     while not e.is_set():
# --> 401         wait(10)
#     403 if error:
#     404     typ, exc, tb = error
#
# File ~/miniconda3/envs/XROMS/lib/python3.8/site-packages/distributed/utils.py:390, in sync.<locals>.wait(timeout)
#     388 def wait(timeout):
#     389     try:
# --> 390         return e.wait(timeout)
#     391     except KeyboardInterrupt:
#     392         loop.add_callback(cancel)
#
# File ~/miniconda3/envs/XROMS/lib/python3.8/threading.py:558, in Event.wait(self, timeout)
#     556 signaled = self._flag
#     557 if not signaled:
# --> 558     signaled = self._cond.wait(timeout)
#     559 return signaled
#
# File ~/miniconda3/envs/XROMS/lib/python3.8/threading.py:306, in Condition.wait(self, timeout)
#     304 else:
#     305     if timeout > 0:
# --> 306         gotit = waiter.acquire(True, timeout)
#     307     else:
#     308         gotit = waiter.acquire(False)
#
# KeyboardInterrupt:

# %%
ix
# Out:
# 267

# %%
MLD_smth.to_netcdf('/homes/metogra/iufarias/Documents/data/MLD/MLD_smth_maps.nc')
# Out:
# 2023-08-16 17:28:20,894 - distributed.nanny - WARNING - Restarting worker
# 2023-08-16 17:28:20,896 - distributed.nanny - WARNING - Restarting worker
# 2023-08-16 17:28:20,899 - distributed.nanny - WARNING - Restarting worker
# 2023-08-16 17:28:21,108 - distributed.nanny - WARNING - Restarting worker
# 2023-08-16 17:28:21,112 - distributed.nanny - WARNING - Restarting worker
# 2023-08-16 17:28:21,342 - distributed.nanny - WARNING - Restarting worker
# 2023-08-16 17:28:21,346 - distributed.nanny - WARNING - Restarting worker
# 2023-08-16 17:28:21,564 - distributed.nanny - WARNING - Restarting worker
# 2023-08-16 17:28:21,569 - distributed.nanny - WARNING - Restarting worker
# 2023-08-16 17:28:21,791 - distributed.nanny - WARNING - Restarting worker
# 2023-08-16 17:28:21,900 - distributed.nanny - WARNING - Restarting worker
# 2023-08-16 17:28:22,013 - distributed.nanny - WARNING - Restarting worker
# 2023-08-16 17:28:22,125 - distributed.nanny - WARNING - Restarting worker
# 2023-08-16 17:28:22,239 - distributed.nanny - WARNING - Restarting worker
# 2023-08-16 17:28:22,243 - distributed.nanny - WARNING - Restarting worker
# 2023-08-16 17:28:22,461 - distributed.nanny - WARNING - Restarting worker
# 2023-08-16 17:28:22,476 - distributed.nanny - WARNING - Restarting worker
# 2023-08-16 17:28:22,635 - distributed.nanny - ERROR - Worker process died unexpectedly
# 2023-08-16 17:28:22,697 - distributed.nanny - WARNING - Restarting worker
# 2023-08-16 17:28:22,700 - distributed.nanny - WARNING - Restarting worker
# 2023-08-16 17:28:22,813 - distributed.nanny - WARNING - Restarting worker
# 2023-08-16 17:28:23,031 - distributed.nanny - WARNING - Restarting worker
# 2023-08-16 17:28:23,143 - distributed.nanny - WARNING - Restarting worker
# 2023-08-16 17:28:23,149 - distributed.nanny - WARNING - Restarting worker
# 2023-08-16 17:28:23,395 - distributed.nanny - WARNING - Restarting worker
# 2023-08-16 17:28:23,511 - distributed.nanny - WARNING - Restarting worker
# 2023-08-16 17:28:23,515 - distributed.nanny - WARNING - Restarting worker
# 2023-08-16 17:28:23,760 - distributed.nanny - WARNING - Restarting worker
# 2023-08-16 17:28:23,765 - distributed.nanny - WARNING - Restarting worker
# 2023-08-16 17:28:23,987 - distributed.nanny - WARNING - Restarting worker
# 2023-08-16 17:28:23,992 - distributed.nanny - WARNING - Restarting worker
# 2023-08-16 17:28:24,101 - distributed.nanny - WARNING - Restarting worker
# 2023-08-16 17:28:24,324 - distributed.nanny - WARNING - Restarting worker
# 2023-08-16 17:28:24,436 - distributed.nanny - WARNING - Restarting worker
# 2023-08-16 17:28:24,552 - distributed.nanny - WARNING - Restarting worker
# 2023-08-16 17:28:24,663 - distributed.nanny - WARNING - Restarting worker
# 2023-08-16 17:28:24,777 - distributed.nanny - WARNING - Restarting worker
# 2023-08-16 17:28:24,782 - distributed.nanny - WARNING - Restarting worker
# 2023-08-16 17:28:24,999 - distributed.nanny - WARNING - Restarting worker
# 2023-08-16 17:28:25,113 - distributed.nanny - WARNING - Restarting worker
# 2023-08-16 17:28:25,225 - distributed.nanny - WARNING - Restarting worker
# 2023-08-16 17:28:25,230 - distributed.nanny - WARNING - Restarting worker
# 2023-08-16 17:28:25,452 - distributed.nanny - WARNING - Restarting worker
# 2023-08-16 17:28:25,456 - distributed.nanny - WARNING - Restarting worker
# 2023-08-16 17:28:25,673 - distributed.nanny - WARNING - Restarting worker
# 2023-08-16 17:28:25,787 - distributed.nanny - WARNING - Restarting worker
# 2023-08-16 17:28:25,791 - distributed.nanny - WARNING - Restarting worker
# 2023-08-16 17:28:25,794 - distributed.nanny - WARNING - Restarting worker
# 2023-08-16 17:28:25,907 - distributed.nanny - WARNING - Restarting worker
# 2023-08-16 17:28:26,234 - distributed.nanny - WARNING - Restarting worker
# 2023-08-16 17:28:26,239 - distributed.nanny - WARNING - Restarting worker
# 2023-08-16 17:28:26,371 - distributed.nanny - WARNING - Restarting worker
# 2023-08-16 17:28:26,482 - distributed.nanny - WARNING - Restarting worker
# 2023-08-16 17:28:26,704 - distributed.nanny - WARNING - Restarting worker
# 2023-08-16 17:28:26,817 - distributed.nanny - WARNING - Restarting worker
# 2023-08-16 17:28:26,931 - distributed.nanny - WARNING - Restarting worker
# 2023-08-16 17:28:26,937 - distributed.nanny - WARNING - Restarting worker
# 2023-08-16 17:28:27,158 - distributed.nanny - WARNING - Restarting worker
# 2023-08-16 17:28:27,163 - distributed.nanny - WARNING - Restarting worker
# 2023-08-16 17:28:27,280 - distributed.nanny - WARNING - Restarting worker
# 2023-08-16 17:28:27,393 - distributed.nanny - WARNING - Restarting worker
# 2023-08-16 17:28:27,529 - distributed.nanny - WARNING - Restarting worker
# 2023-08-16 17:28:27,763 - distributed.nanny - WARNING - Restarting worker
# 2023-08-16 17:28:27,767 - distributed.nanny - WARNING - Restarting worker
# 2023-08-16 17:28:28,106 - distributed.nanny - WARNING - Restarting worker
# 2023-08-16 17:28:28,109 - distributed.nanny - WARNING - Restarting worker
# 2023-08-16 17:28:28,112 - distributed.nanny - WARNING - Restarting worker
# 2023-08-16 17:28:28,224 - distributed.nanny - WARNING - Restarting worker
# 2023-08-16 17:28:28,230 - distributed.nanny - WARNING - Restarting worker
# 2023-08-16 17:28:28,341 - distributed.nanny - WARNING - Restarting worker
# 2023-08-16 17:28:28,455 - distributed.nanny - WARNING - Restarting worker
# 2023-08-16 17:28:28,462 - distributed.nanny - WARNING - Restarting worker
# 2023-08-16 17:28:28,788 - distributed.nanny - WARNING - Restarting worker
# 2023-08-16 17:28:28,793 - distributed.nanny - WARNING - Restarting worker
# 2023-08-16 17:28:28,904 - distributed.nanny - WARNING - Restarting worker
# 2023-08-16 17:28:29,126 - distributed.nanny - WARNING - Restarting worker
# 2023-08-16 17:28:29,571 - distributed.nanny - WARNING - Restarting worker
# 2023-08-16 17:28:29,573 - distributed.nanny - WARNING - Restarting worker
# 2023-08-16 17:28:29,576 - distributed.nanny - WARNING - Restarting worker
# 2023-08-16 17:28:29,686 - distributed.nanny - WARNING - Restarting worker
# 2023-08-16 17:28:29,902 - distributed.nanny - WARNING - Restarting worker
# 2023-08-16 17:28:29,908 - distributed.nanny - WARNING - Restarting worker
# 2023-08-16 17:28:29,910 - distributed.nanny - WARNING - Restarting worker
# 2023-08-16 17:28:30,045 - distributed.nanny - WARNING - Restarting worker
# 2023-08-16 17:28:30,268 - distributed.nanny - WARNING - Restarting worker
# 2023-08-16 17:28:30,485 - distributed.nanny - WARNING - Restarting worker
# 2023-08-16 17:28:30,490 - distributed.nanny - WARNING - Restarting worker
# 2023-08-16 17:28:30,619 - distributed.nanny - WARNING - Restarting worker
# 2023-08-16 17:28:30,624 - distributed.nanny - WARNING - Restarting worker
# 2023-08-16 17:28:30,633 - distributed.nanny - WARNING - Restarting worker
# 2023-08-16 17:28:31,210 - distributed.worker_memory - WARNING - Worker tcp://127.0.0.1:33618 (pid=41095) exceeded 95% memory budget. Restarting...
# 2023-08-16 17:28:31,346 - distributed.nanny - WARNING - Restarting worker
# 2023-08-16 17:28:31,527 - distributed.nanny - WARNING - Restarting worker

# %%
dbool=True
slog=False

a1=0.4
a2=0.4
lw=2
HT='step'

plt.figure(figsize=(10,10))
plt.hist(np.ravel((MLD_full)),bins=100,color='tomato',linewidth=lw,histtype=HT,alpha=a2,density=dbool,log=slog)
plt.hist(np.ravel((MLD_smth)),bins=100,color='cornflowerblue',linewidth=lw,histtype=HT,alpha=a1,density=dbool,log=slog)
plt.xlabel(r'$MLD$[m]')
# Out:
# Text(0.5, 0, '$MLD$[m]')
